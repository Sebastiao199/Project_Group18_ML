# %% [markdown]
# ## Import the needed Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# data partition
from sklearn.model_selection import train_test_split

#filter methods
# spearman 
# chi-square
import scipy.stats as stats
from scipy.stats import chi2_contingency

#wrapper methods
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.feature_selection import RFE


# embedded methods
from sklearn.linear_model import LassoCV

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Import the dataset

# %%
train = pd.read_csv('/Users/tomasverissimo/Desktop/Master/1st Year/1st Semester/Machine Learning/Project/project_data/train.csv')
train.head()
# Out:
#    encounter_id country  patient_id             race  gender      age weight  \
# 0        533253     USA       70110        Caucasian  Female  [70-80)      ?
# 1        426224     USA    29775006  AfricanAmerican    Male  [50-60)      ?
# 2        634063     USA    80729253        Caucasian  Female  [60-70)      ?
# 3        890610     USA     2919042  AfricanAmerican    Male  [60-70)      ?
# 4        654194     USA    84871971        Caucasian  Female  [70-80)      ?
#
#   payer_code  outpatient_visits_in_previous_year  \
# 0          ?                                   0
# 1          ?                                   0
# 2          ?                                   0
# 3         MC                                   0
# 4         HM                                   1
#
#    emergency_visits_in_previous_year  ...  secondary_diagnosis  \
# 0                                  0  ...                  276
# 1                                  0  ...                  785
# 2                                  0  ...                  135
# 3                                  0  ...                  562
# 4                                  0  ...                  599
#
#   additional_diagnosis number_diagnoses  glucose_test_result a1c_test_result  \
# 0                  466                8                  NaN             NaN
# 1                  162                9                  NaN             NaN
# 2                  250                6                  NaN             NaN
# 3                  455                5                  NaN             NaN
# 4                  428                9                  NaN             NaN
#
#   change_in_meds_during_hospitalization  prescribed_diabetes_meds  \
# 0                                    No                        No
# 1                                    No                       Yes
# 2                                    Ch                       Yes
# 3                                    No                        No
# 4                                    No                        No
#
#                    medication  readmitted_binary  readmitted_multiclass
# 0                          []                 No               >30 days
# 1                 ['insulin']                 No                     No
# 2  ['glimepiride', 'insulin']                 No                     No
# 3                          []                 No                     No
# 4                          []                 No               >30 days
#
# [5 rows x 31 columns]

# %% [markdown]
# ## See the data

# %%
train.set_index('patient_id', inplace = True)

# %%
train['readmitted_binary'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
train.describe(include = 'all').T
# Out:
#                                          count unique                 top  \
# encounter_id                           71236.0    NaN                 NaN
# country                                  71236      1                 USA
# race                                     67682      6           Caucasian
# gender                                   71236      3              Female
# age                                      67679     10             [70-80)
# weight                                   71236     10                   ?
# payer_code                               71236     18                   ?
# outpatient_visits_in_previous_year     71236.0    NaN                 NaN
# emergency_visits_in_previous_year      71236.0    NaN                 NaN
# inpatient_visits_in_previous_year      71236.0    NaN                 NaN
# admission_type                           67530      7           Emergency
# medical_specialty                        71236     69                   ?
# average_pulse_bpm                      71236.0    NaN                 NaN
# discharge_disposition                    68646     25  Discharged to home
# admission_source                         66518     16      Emergency Room
# length_of_stay_in_hospital             71236.0    NaN                 NaN
# number_lab_tests                       71236.0    NaN                 NaN
# non_lab_procedures                     71236.0    NaN                 NaN
# number_of_medications                  71236.0    NaN                 NaN
# primary_diagnosis                        71236    687                 428
# secondary_diagnosis                      71236    699                 276
# additional_diagnosis                     71236    747                 250
# number_diagnoses                       71236.0    NaN                 NaN
# glucose_test_result                       3688      3                Norm
# a1c_test_result                          11916      3                  >8
# change_in_meds_during_hospitalization    71236      2                  No
# prescribed_diabetes_meds                 71236      2                 Yes
# medication                               71236    303         ['insulin']
# readmitted_binary                        71236      2                  No
# readmitted_multiclass                    71236      3                  No
#
#                                         freq           mean            std  \
# encounter_id                             NaN  548798.623716  259704.723154
# country                                71236            NaN            NaN
# race                                   50693            NaN            NaN
# gender                                 38228            NaN            NaN
# age                                    17359            NaN            NaN
# weight                                 68990            NaN            NaN
# payer_code                             28201            NaN            NaN
# outpatient_visits_in_previous_year       NaN       0.369588       1.287469
# emergency_visits_in_previous_year        NaN       0.196249       0.910854
# inpatient_visits_in_previous_year        NaN       0.640154       1.267271
# admission_type                         37742            NaN            NaN
# medical_specialty                      34922            NaN            NaN
# average_pulse_bpm                        NaN      99.611222      23.040521
# discharge_disposition                  42256            NaN            NaN
# admission_source                       40319            NaN            NaN
# length_of_stay_in_hospital               NaN       4.391024       2.988739
# number_lab_tests                         NaN      43.095654      19.642919
# non_lab_procedures                       NaN       1.340923       1.706664
# number_of_medications                    NaN      15.995452       8.122347
# primary_diagnosis                       4776            NaN            NaN
# secondary_diagnosis                     4694            NaN            NaN
# additional_diagnosis                    8070            NaN            NaN
# number_diagnoses                         NaN       7.421023       1.937809
# glucose_test_result                     1806            NaN            NaN
# a1c_test_result                         5705            NaN            NaN
# change_in_meds_during_hospitalization  38326            NaN            NaN
# prescribed_diabetes_meds               54890            NaN            NaN
# medication                             21715            NaN            NaN
# readmitted_binary                      63286            NaN            NaN
# readmitted_multiclass                  38405            NaN            NaN
#
#                                             min       25%       50%       75%  \
# encounter_id                           100000.0  323118.5  548370.0  774058.5
# country                                     NaN       NaN       NaN       NaN
# race                                        NaN       NaN       NaN       NaN
# gender                                      NaN       NaN       NaN       NaN
# age                                         NaN       NaN       NaN       NaN
# weight                                      NaN       NaN       NaN       NaN
# payer_code                                  NaN       NaN       NaN       NaN
# outpatient_visits_in_previous_year          0.0       0.0       0.0       0.0
# emergency_visits_in_previous_year           0.0       0.0       0.0       0.0
# inpatient_visits_in_previous_year           0.0       0.0       0.0       1.0
# admission_type                              NaN       NaN       NaN       NaN
# medical_specialty                           NaN       NaN       NaN       NaN
# average_pulse_bpm                          60.0      80.0     100.0     119.0
# discharge_disposition                       NaN       NaN       NaN       NaN
# admission_source                            NaN       NaN       NaN       NaN
# length_of_stay_in_hospital                  1.0       2.0       4.0       6.0
# number_lab_tests                            1.0      31.0      44.0      57.0
# non_lab_procedures                          0.0       0.0       1.0       2.0
# number_of_medications                       1.0      10.0      15.0      20.0
# primary_diagnosis                           NaN       NaN       NaN       NaN
# secondary_diagnosis                         NaN       NaN       NaN       NaN
# additional_diagnosis                        NaN       NaN       NaN       NaN
# number_diagnoses                            1.0       6.0       8.0       9.0
# glucose_test_result                         NaN       NaN       NaN       NaN
# a1c_test_result                             NaN       NaN       NaN       NaN
# change_in_meds_during_hospitalization       NaN       NaN       NaN       NaN
# prescribed_diabetes_meds                    NaN       NaN       NaN       NaN
# medication                                  NaN       NaN       NaN       NaN
# readmitted_binary                           NaN       NaN       NaN       NaN
# readmitted_multiclass                       NaN       NaN       NaN       NaN
#
#                                             max
# encounter_id                           999980.0
# country                                     NaN
# race                                        NaN
# gender                                      NaN
# age                                         NaN
# weight                                      NaN
# payer_code                                  NaN
# outpatient_visits_in_previous_year         42.0
# emergency_visits_in_previous_year          76.0
# inpatient_visits_in_previous_year          21.0
# admission_type                              NaN
# medical_specialty                           NaN
# average_pulse_bpm                         139.0
# discharge_disposition                       NaN
# admission_source                            NaN
# length_of_stay_in_hospital                 14.0
# number_lab_tests                          121.0
# non_lab_procedures                          6.0
# number_of_medications                      75.0
# primary_diagnosis                           NaN
# secondary_diagnosis                         NaN
# additional_diagnosis                        NaN
# number_diagnoses                           16.0
# glucose_test_result                         NaN
# a1c_test_result                             NaN
# change_in_meds_during_hospitalization       NaN
# prescribed_diabetes_meds                    NaN
# medication                                  NaN
# readmitted_binary                           NaN
# readmitted_multiclass                       NaN

# %%
train.dtypes
# Out:
# encounter_id                              int64
# country                                  object
# race                                     object
# gender                                   object
# age                                      object
# weight                                   object
# payer_code                               object
# outpatient_visits_in_previous_year        int64
# emergency_visits_in_previous_year         int64
# inpatient_visits_in_previous_year         int64
# admission_type                           object
# medical_specialty                        object
# average_pulse_bpm                         int64
# discharge_disposition                    object
# admission_source                         object
# length_of_stay_in_hospital                int64
# number_lab_tests                          int64
# non_lab_procedures                        int64
# number_of_medications                     int64
# primary_diagnosis                        object
# secondary_diagnosis                      object
# additional_diagnosis                     object
# number_diagnoses                          int64
# glucose_test_result                      object
# a1c_test_result                          object
# change_in_meds_during_hospitalization    object
# prescribed_diabetes_meds                 object
# medication                               object
# readmitted_binary                        object
# readmitted_multiclass                    object
# dtype: object

# %%
non_metric_features = ['country', 'race', 'gender', 'age', 'payer_code', 'admission_type', 'medical_specialty', 'discharge_disposition', 'admission_source', 'primary_diagnosis', 'secondary_diagnosis', 'additional_diagnosis', 'change_in_meds_during_hospitalization', 'prescribed_diabetes_meds', 'medication']
metric_features = train.columns.drop(non_metric_features).tolist()

# %% [markdown]
# ## Treatment of missing values

# %%
train_central = train.copy()

# %%
train_central.isna().sum()
# Out:
# encounter_id                                 0
# country                                      0
# race                                      3554
# gender                                       0
# age                                       3557
# weight                                       0
# payer_code                                   0
# outpatient_visits_in_previous_year           0
# emergency_visits_in_previous_year            0
# inpatient_visits_in_previous_year            0
# admission_type                            3706
# medical_specialty                            0
# average_pulse_bpm                            0
# discharge_disposition                     2590
# admission_source                          4718
# length_of_stay_in_hospital                   0
# number_lab_tests                             0
# non_lab_procedures                           0
# number_of_medications                        0
# primary_diagnosis                            0
# secondary_diagnosis                          0
# additional_diagnosis                         0
# number_diagnoses                             0
# glucose_test_result                      67548
# a1c_test_result                          59320
# change_in_meds_during_hospitalization        0
# prescribed_diabetes_meds                     0
# medication                                   0
# readmitted_binary                            0
# readmitted_multiclass                        0
# dtype: int64

# %%
train_central.replace('?', np.nan, inplace = True)
train_central.replace('[]', np.nan, inplace = True)

# %%
train_central.drop(['weight','glucose_test_result', 'a1c_test_result'], axis=1, inplace=True)

# %%
train_central.drop(['readmitted_multiclass'], axis=1, inplace=True)

# %%
train_central
# Out:
#             encounter_id country             race  gender      age payer_code  \
# patient_id
# 70110             533253     USA        Caucasian  Female  [70-80)        NaN
# 29775006          426224     USA  AfricanAmerican    Male  [50-60)        NaN
# 80729253          634063     USA        Caucasian  Female  [60-70)        NaN
# 2919042           890610     USA  AfricanAmerican    Male  [60-70)         MC
# 84871971          654194     USA        Caucasian  Female  [70-80)         HM
# ...                  ...     ...              ...     ...      ...        ...
# 24531381          660160     USA  AfricanAmerican  Female  [80-90)         MC
# 4663818           826429     USA  AfricanAmerican  Female  [70-80)        NaN
# 23397147          332030     USA        Caucasian  Female  [60-70)        NaN
# 52161750          757560     USA        Caucasian    Male  [60-70)         BC
# 88410897          459757     USA        Caucasian    Male  [70-80)         BC
#
#             outpatient_visits_in_previous_year  \
# patient_id
# 70110                                        0
# 29775006                                     0
# 80729253                                     0
# 2919042                                      0
# 84871971                                     1
# ...                                        ...
# 24531381                                     0
# 4663818                                      0
# 23397147                                     0
# 52161750                                     0
# 88410897                                     0
#
#             emergency_visits_in_previous_year  \
# patient_id
# 70110                                       0
# 29775006                                    0
# 80729253                                    0
# 2919042                                     0
# 84871971                                    0
# ...                                       ...
# 24531381                                    1
# 4663818                                     0
# 23397147                                    2
# 52161750                                    0
# 88410897                                    0
#
#             inpatient_visits_in_previous_year admission_type  ...  \
# patient_id                                                    ...
# 70110                                       2      Emergency  ...
# 29775006                                    0      Emergency  ...
# 80729253                                    1            NaN  ...
# 2919042                                     1      Emergency  ...
# 84871971                                    0       Elective  ...
# ...                                       ...            ...  ...
# 24531381                                    0       Elective  ...
# 4663818                                     0         Urgent  ...
# 23397147                                    2            NaN  ...
# 52161750                                    2      Emergency  ...
# 88410897                                    1         Urgent  ...
#
#            non_lab_procedures  number_of_medications primary_diagnosis  \
# patient_id
# 70110                       0                     20               515
# 29775006                    0                     25                38
# 80729253                    1                     22               534
# 2919042                     2                      9               569
# 84871971                    1                     15               715
# ...                       ...                    ...               ...
# 24531381                    1                     18               453
# 4663818                     0                      9               157
# 23397147                    0                     24               428
# 52161750                    1                     13               820
# 88410897                    2                      9               434
#
#            secondary_diagnosis  additional_diagnosis  number_diagnoses  \
# patient_id
# 70110                      276                   466                 8
# 29775006                   785                   162                 9
# 80729253                   135                   250                 6
# 2919042                    562                   455                 5
# 84871971                   599                   428                 9
# ...                        ...                   ...               ...
# 24531381                   786                   250                 9
# 4663818                    197                   V66                 6
# 23397147                   491                   276                 9
# 52161750                   157                 250.8                 5
# 88410897                   250                   401                 8
#
#             change_in_meds_during_hospitalization  prescribed_diabetes_meds  \
# patient_id
# 70110                                          No                        No
# 29775006                                       No                       Yes
# 80729253                                       Ch                       Yes
# 2919042                                        No                        No
# 84871971                                       No                        No
# ...                                           ...                       ...
# 24531381                                       Ch                       Yes
# 4663818                                        Ch                       Yes
# 23397147                                       Ch                       Yes
# 52161750                                       Ch                       Yes
# 88410897                                       Ch                       Yes
#
#                                        medication readmitted_binary
# patient_id
# 70110                                         NaN                No
# 29775006                              ['insulin']                No
# 80729253               ['glimepiride', 'insulin']                No
# 2919042                                       NaN                No
# 84871971                                      NaN                No
# ...                                           ...               ...
# 24531381    ['metformin', 'glyburide', 'insulin']                No
# 4663818                ['metformin', 'glyburide']                No
# 23397147                 ['glyburide', 'insulin']               Yes
# 52161750                 ['glyburide', 'insulin']                No
# 88410897                              ['insulin']                No
#
# [71236 rows x 26 columns]

# %%
medians = train_central.median(numeric_only = True)
medians
train_central.fillna(medians, inplace = True)

# %%
modes = train_central[non_metric_features].mode().loc[0]

# %%
train_central.fillna(modes, inplace= True)

# %%
# Seeing rows with NaNs
nans_index = train_central.isna().any(axis=1)
train_central[nans_index] #this function is like a filter, only shows the ones that match the condition of the variable, 
#i.e. that have missing values
# Out:
# Empty DataFrame
# Columns: [encounter_id, country, race, gender, age, payer_code, outpatient_visits_in_previous_year, emergency_visits_in_previous_year, inpatient_visits_in_previous_year, admission_type, medical_specialty, average_pulse_bpm, discharge_disposition, admission_source, length_of_stay_in_hospital, number_lab_tests, non_lab_procedures, number_of_medications, primary_diagnosis, secondary_diagnosis, additional_diagnosis, number_diagnoses, change_in_meds_during_hospitalization, prescribed_diabetes_meds, medication, readmitted_binary]
# Index: []
#
# [0 rows x 26 columns]

# %%
train_central
# Out:
#             encounter_id country             race  gender      age payer_code  \
# patient_id
# 70110             533253     USA        Caucasian  Female  [70-80)         MC
# 29775006          426224     USA  AfricanAmerican    Male  [50-60)         MC
# 80729253          634063     USA        Caucasian  Female  [60-70)         MC
# 2919042           890610     USA  AfricanAmerican    Male  [60-70)         MC
# 84871971          654194     USA        Caucasian  Female  [70-80)         HM
# ...                  ...     ...              ...     ...      ...        ...
# 24531381          660160     USA  AfricanAmerican  Female  [80-90)         MC
# 4663818           826429     USA  AfricanAmerican  Female  [70-80)         MC
# 23397147          332030     USA        Caucasian  Female  [60-70)         MC
# 52161750          757560     USA        Caucasian    Male  [60-70)         BC
# 88410897          459757     USA        Caucasian    Male  [70-80)         BC
#
#             outpatient_visits_in_previous_year  \
# patient_id
# 70110                                        0
# 29775006                                     0
# 80729253                                     0
# 2919042                                      0
# 84871971                                     1
# ...                                        ...
# 24531381                                     0
# 4663818                                      0
# 23397147                                     0
# 52161750                                     0
# 88410897                                     0
#
#             emergency_visits_in_previous_year  \
# patient_id
# 70110                                       0
# 29775006                                    0
# 80729253                                    0
# 2919042                                     0
# 84871971                                    0
# ...                                       ...
# 24531381                                    1
# 4663818                                     0
# 23397147                                    2
# 52161750                                    0
# 88410897                                    0
#
#             inpatient_visits_in_previous_year admission_type  ...  \
# patient_id                                                    ...
# 70110                                       2      Emergency  ...
# 29775006                                    0      Emergency  ...
# 80729253                                    1      Emergency  ...
# 2919042                                     1      Emergency  ...
# 84871971                                    0       Elective  ...
# ...                                       ...            ...  ...
# 24531381                                    0       Elective  ...
# 4663818                                     0         Urgent  ...
# 23397147                                    2      Emergency  ...
# 52161750                                    2      Emergency  ...
# 88410897                                    1         Urgent  ...
#
#            non_lab_procedures  number_of_medications primary_diagnosis  \
# patient_id
# 70110                       0                     20               515
# 29775006                    0                     25                38
# 80729253                    1                     22               534
# 2919042                     2                      9               569
# 84871971                    1                     15               715
# ...                       ...                    ...               ...
# 24531381                    1                     18               453
# 4663818                     0                      9               157
# 23397147                    0                     24               428
# 52161750                    1                     13               820
# 88410897                    2                      9               434
#
#            secondary_diagnosis  additional_diagnosis  number_diagnoses  \
# patient_id
# 70110                      276                   466                 8
# 29775006                   785                   162                 9
# 80729253                   135                   250                 6
# 2919042                    562                   455                 5
# 84871971                   599                   428                 9
# ...                        ...                   ...               ...
# 24531381                   786                   250                 9
# 4663818                    197                   V66                 6
# 23397147                   491                   276                 9
# 52161750                   157                 250.8                 5
# 88410897                   250                   401                 8
#
#             change_in_meds_during_hospitalization  prescribed_diabetes_meds  \
# patient_id
# 70110                                          No                        No
# 29775006                                       No                       Yes
# 80729253                                       Ch                       Yes
# 2919042                                        No                        No
# 84871971                                       No                        No
# ...                                           ...                       ...
# 24531381                                       Ch                       Yes
# 4663818                                        Ch                       Yes
# 23397147                                       Ch                       Yes
# 52161750                                       Ch                       Yes
# 88410897                                       Ch                       Yes
#
#                                        medication readmitted_binary
# patient_id
# 70110                                 ['insulin']                No
# 29775006                              ['insulin']                No
# 80729253               ['glimepiride', 'insulin']                No
# 2919042                               ['insulin']                No
# 84871971                              ['insulin']                No
# ...                                           ...               ...
# 24531381    ['metformin', 'glyburide', 'insulin']                No
# 4663818                ['metformin', 'glyburide']                No
# 23397147                 ['glyburide', 'insulin']               Yes
# 52161750                 ['glyburide', 'insulin']                No
# 88410897                              ['insulin']                No
#
# [71236 rows x 26 columns]

# %%
train_central.isna().sum()
# Out:
# encounter_id             0
# race                     0
# gender                   0
# age                      0
# payer_code               0
# outpatient_visits        0
# emergency_visits         0
# inpatient_visits         0
# admission_type           0
# medical_specialty        0
# average_pulse_bpm        0
# discharge_disposition    0
# admission_source         0
# length_of_stay           0
# number_lab_tests         0
# non_lab_procedures       0
# number_of_medications    0
# primary_diagnosis        0
# secondary_diagnosis      0
# additional_diagnosis     0
# number_diagnoses         0
# change_in_meds           0
# diabetes_meds            0
# medication               0
# readmitted_binary        0
# dtype: int64

# %% [markdown]
# ## Substitute column names

# %%
new_column_names = {'outpatient_visits_in_previous_year': 'outpatient_visits', 
                    'emergency_visits_in_previous_year': 'emergency_visits',
                    'inpatient_visits_in_previous_year': 'inpatient_visits',
                    'change_in_meds_during_hospitalization': 'change_in_meds',
                    'length_of_stay_in_hospital': 'length_of_stay',
                    'prescribed_diabetes_meds': 'diabetes_meds'
                   }
train_central = train_central.rename(columns=new_column_names)

# %%
train_central.head()
# Out:
#             encounter_id country             race  gender      age payer_code  \
# patient_id
# 70110             533253     USA        Caucasian  Female  [70-80)         MC
# 29775006          426224     USA  AfricanAmerican    Male  [50-60)         MC
# 80729253          634063     USA        Caucasian  Female  [60-70)         MC
# 2919042           890610     USA  AfricanAmerican    Male  [60-70)         MC
# 84871971          654194     USA        Caucasian  Female  [70-80)         HM
#
#             outpatient_visits  emergency_visits  inpatient_visits  \
# patient_id
# 70110                       0                 0                 2
# 29775006                    0                 0                 0
# 80729253                    0                 0                 1
# 2919042                     0                 0                 1
# 84871971                    1                 0                 0
#
#            admission_type  ... non_lab_procedures  number_of_medications  \
# patient_id                 ...
# 70110           Emergency  ...                  0                     20
# 29775006        Emergency  ...                  0                     25
# 80729253        Emergency  ...                  1                     22
# 2919042         Emergency  ...                  2                      9
# 84871971         Elective  ...                  1                     15
#
#            primary_diagnosis secondary_diagnosis  additional_diagnosis  \
# patient_id
# 70110                    515                 276                   466
# 29775006                  38                 785                   162
# 80729253                 534                 135                   250
# 2919042                  569                 562                   455
# 84871971                 715                 599                   428
#
#             number_diagnoses  change_in_meds  diabetes_meds  \
# patient_id
# 70110                      8              No             No
# 29775006                   9              No            Yes
# 80729253                   6              Ch            Yes
# 2919042                    5              No             No
# 84871971                   9              No             No
#
#                             medication readmitted_binary
# patient_id
# 70110                      ['insulin']                No
# 29775006                   ['insulin']                No
# 80729253    ['glimepiride', 'insulin']                No
# 2919042                    ['insulin']                No
# 84871971                   ['insulin']                No
#
# [5 rows x 26 columns]

# %%
train_central.drop('country', axis = 1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 train_central.drop('country', axis = 1, inplace = True)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:5347, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5199 def drop(
#    5200     self,
#    5201     labels: IndexLabel | None = None,
#    (...)
#    5208     errors: IgnoreRaise = "raise",
#    5209 ) -> DataFrame | None:
#    5210     """
#    5211     Drop specified labels from rows or columns.
#    5212
#    (...)
#    5345             weight  1.0     0.8
#    5346     """
# -> 5347     return super().drop(
#    5348         labels=labels,
#    5349         axis=axis,
#    5350         index=index,
#    5351         columns=columns,
#    5352         level=level,
#    5353         inplace=inplace,
#    5354         errors=errors,
#    5355     )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:4711, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4709 for axis, labels in axes.items():
#    4710     if labels is not None:
# -> 4711         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4713 if inplace:
#    4714     self._update_inplace(obj)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:4753, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4751         new_axis = axis.drop(labels, level=level, errors=errors)
#    4752     else:
# -> 4753         new_axis = axis.drop(labels, errors=errors)
#    4754     indexer = axis.get_indexer(new_axis)
#    4756 # Case for non-unique axis
#    4757 else:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:6992, in Index.drop(self, labels, errors)
#    6990 if mask.any():
#    6991     if errors != "ignore":
# -> 6992         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    6993     indexer = indexer[~mask]
#    6994 return self.delete(indexer)
#
# KeyError: "['country'] not found in axis"

# %% [markdown]
# ## Categorical Data Encoding

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
label_encoder.fit(train_central['age'])
train_central['age'] = label_encoder.transform(train_central['age'])
train_central
# Out:
#             encounter_id             race  gender  age payer_code  \
# patient_id
# 70110             533253        Caucasian  Female    7         MC
# 29775006          426224  AfricanAmerican    Male    5         MC
# 80729253          634063        Caucasian  Female    6         MC
# 2919042           890610  AfricanAmerican    Male    6         MC
# 84871971          654194        Caucasian  Female    7         HM
# ...                  ...              ...     ...  ...        ...
# 24531381          660160  AfricanAmerican  Female    8         MC
# 4663818           826429  AfricanAmerican  Female    7         MC
# 23397147          332030        Caucasian  Female    6         MC
# 52161750          757560        Caucasian    Male    6         BC
# 88410897          459757        Caucasian    Male    7         BC
#
#             outpatient_visits  emergency_visits  inpatient_visits  \
# patient_id
# 70110                       0                 0                 2
# 29775006                    0                 0                 0
# 80729253                    0                 0                 1
# 2919042                     0                 0                 1
# 84871971                    1                 0                 0
# ...                       ...               ...               ...
# 24531381                    0                 1                 0
# 4663818                     0                 0                 0
# 23397147                    0                 2                 2
# 52161750                    0                 0                 2
# 88410897                    0                 0                 1
#
#            admission_type       medical_specialty  ...  non_lab_procedures  \
# patient_id                                         ...
# 70110           Emergency  Family/GeneralPractice  ...                   0
# 29775006        Emergency        InternalMedicine  ...                   0
# 80729253        Emergency  Family/GeneralPractice  ...                   1
# 2919042         Emergency        InternalMedicine  ...                   2
# 84871971         Elective        InternalMedicine  ...                   1
# ...                   ...                     ...  ...                 ...
# 24531381         Elective        InternalMedicine  ...                   1
# 4663818            Urgent        InternalMedicine  ...                   0
# 23397147        Emergency        InternalMedicine  ...                   0
# 52161750        Emergency        Emergency/Trauma  ...                   1
# 88410897           Urgent         Surgery-General  ...                   2
#
#            number_of_medications primary_diagnosis  secondary_diagnosis  \
# patient_id
# 70110                         20               515                  276
# 29775006                      25                38                  785
# 80729253                      22               534                  135
# 2919042                        9               569                  562
# 84871971                      15               715                  599
# ...                          ...               ...                  ...
# 24531381                      18               453                  786
# 4663818                        9               157                  197
# 23397147                      24               428                  491
# 52161750                      13               820                  157
# 88410897                       9               434                  250
#
#             additional_diagnosis  number_diagnoses  change_in_meds  \
# patient_id
# 70110                        466                 8              No
# 29775006                     162                 9              No
# 80729253                     250                 6              Ch
# 2919042                      455                 5              No
# 84871971                     428                 9              No
# ...                          ...               ...             ...
# 24531381                     250                 9              Ch
# 4663818                      V66                 6              Ch
# 23397147                     276                 9              Ch
# 52161750                   250.8                 5              Ch
# 88410897                     401                 8              Ch
#
#            diabetes_meds                             medication  \
# patient_id
# 70110                 No                            ['insulin']
# 29775006             Yes                            ['insulin']
# 80729253             Yes             ['glimepiride', 'insulin']
# 2919042               No                            ['insulin']
# 84871971              No                            ['insulin']
# ...                  ...                                    ...
# 24531381             Yes  ['metformin', 'glyburide', 'insulin']
# 4663818              Yes             ['metformin', 'glyburide']
# 23397147             Yes               ['glyburide', 'insulin']
# 52161750             Yes               ['glyburide', 'insulin']
# 88410897             Yes                            ['insulin']
#
#            readmitted_binary
# patient_id
# 70110                     No
# 29775006                  No
# 80729253                  No
# 2919042                   No
# 84871971                  No
# ...                      ...
# 24531381                  No
# 4663818                   No
# 23397147                 Yes
# 52161750                  No
# 88410897                  No
#
# [71236 rows x 25 columns]

# %%
from sklearn.preprocessing import OrdinalEncoder
enc1 = OrdinalEncoder()

# %%
numerical_columns = train_central.select_dtypes(include=np.number).columns
categorical_columns = pd.DataFrame(train_central.drop(numerical_columns, axis=1))

# %%
enc1.fit(categorical_columns)
train_encoded = pd.DataFrame(enc1.transform(categorical_columns), columns = categorical_columns.columns)
train_encoded.set_index(train.index, inplace=True)
train_encoded
# Out:
#             race  gender  payer_code  admission_type  medical_specialty  \
# patient_id
# 70110        2.0     0.0         7.0             1.0               10.0
# 29775006     0.0     1.0         7.0             1.0               17.0
# 80729253     2.0     0.0         7.0             1.0               10.0
# 2919042      0.0     1.0         7.0             1.0               17.0
# 84871971     2.0     0.0         6.0             0.0               17.0
# ...          ...     ...         ...             ...                ...
# 24531381     0.0     0.0         7.0             0.0               17.0
# 4663818      0.0     0.0         7.0             6.0               17.0
# 23397147     2.0     0.0         7.0             1.0               17.0
# 52161750     2.0     1.0         0.0             1.0                7.0
# 88410897     2.0     1.0         0.0             6.0               59.0
#
#             discharge_disposition  admission_source  primary_diagnosis  \
# patient_id
# 70110                         1.0               1.0              337.0
# 29775006                      4.0              12.0              229.0
# 80729253                      1.0               1.0              355.0
# 2919042                       1.0               9.0              379.0
# 84871971                     11.0               5.0              488.0
# ...                           ...               ...                ...
# 24531381                      1.0               5.0              289.0
# 4663818                       1.0               5.0               24.0
# 23397147                     23.0               1.0              267.0
# 52161750                      3.0               1.0              557.0
# 88410897                      1.0               1.0              273.0
#
#             secondary_diagnosis  additional_diagnosis  change_in_meds  \
# patient_id
# 70110                     122.0                 291.0             1.0
# 29775006                  485.0                  24.0             1.0
# 80729253                   10.0                  80.0             0.0
# 2919042                   345.0                 281.0             1.0
# 84871971                  377.0                 257.0             1.0
# ...                         ...                   ...             ...
# 24531381                  486.0                  80.0             0.0
# 4663818                    39.0                 741.0             0.0
# 23397147                  297.0                 131.0             0.0
# 52161750                   22.0                 103.0             0.0
# 88410897                   70.0                 235.0             0.0
#
#             diabetes_meds  medication  readmitted_binary
# patient_id
# 70110                 0.0        92.0                0.0
# 29775006              1.0        92.0                0.0
# 80729253              1.0        25.0                0.0
# 2919042               0.0        92.0                0.0
# 84871971              0.0        92.0                0.0
# ...                   ...         ...                ...
# 24531381              1.0       144.0                0.0
# 4663818               1.0       155.0                0.0
# 23397147              1.0        73.0                1.0
# 52161750              1.0        73.0                0.0
# 88410897              1.0        92.0                0.0
#
# [71236 rows x 14 columns]

# %%
train_encoded.isna().sum()
# Out:
# race                     0
# gender                   0
# payer_code               0
# admission_type           0
# medical_specialty        0
# discharge_disposition    0
# admission_source         0
# primary_diagnosis        0
# secondary_diagnosis      0
# additional_diagnosis     0
# change_in_meds           0
# diabetes_meds            0
# medication               0
# readmitted_binary        0
# dtype: int64

# %%
import numpy as np
import pandas as pd
import missingno as msno
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
import scipy.stats as stats
from scipy.stats import pointbiserialr
from scipy.stats import chi2_contingency
#wrapper methods
from sklearn.feature_selection import RFE
from sklearn.feature_selection import RFECV


from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import make_scorer
from sklearn.metrics import f1_score


from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

#scaler methods
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

# embedded methods
from sklearn.linear_model import LassoCV

from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OrdinalEncoder

import warnings
warnings.filterwarnings('ignore')

from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingClassifier

# %% [markdown]
# # Importing the datasets

# %%
sample_submission = pd.read_csv('https://raw.githubusercontent.com/Sebastiao199/Project_Group18_ML/main/sample_submission.csv')
sample_submission.head()
# Out:
#    encounter_id readmitted_binary
# 0        499502                No
# 1        447319                No
# 2        309126               Yes
# 3        181183               Yes
# 4        359339                No

# %%
test = pd.read_csv('https://raw.githubusercontent.com/Sebastiao199/Project_Group18_ML/main/test.csv', na_values=['?', ''], index_col='encounter_id')
test.head()
# Out:
#              country  patient_id             race gender      age weight  \
# encounter_id
# 499502           USA   103232799        Caucasian   Male  [80-90)    NaN
# 447319           USA    93395304        Caucasian   Male  [20-30)    NaN
# 309126           USA     6281586  AfricanAmerican   Male  [30-40)    NaN
# 181183           USA    67381308        Caucasian   Male  [50-60)    NaN
# 359339           USA    71670204        Caucasian   Male  [60-70)    NaN
#
#              payer_code  outpatient_visits_in_previous_year  \
# encounter_id
# 499502               HM                                   0
# 447319               HM                                   0
# 309126              NaN                                   0
# 181183               BC                                   0
# 359339              NaN                                   0
#
#               emergency_visits_in_previous_year  \
# encounter_id
# 499502                                        0
# 447319                                        0
# 309126                                        0
# 181183                                        0
# 359339                                        0
#
#               inpatient_visits_in_previous_year  ... number_of_medications  \
# encounter_id                                     ...
# 499502                                        0  ...                    14
# 447319                                        1  ...                     7
# 309126                                        0  ...                    12
# 181183                                        0  ...                    16
# 359339                                        0  ...                    10
#
#              primary_diagnosis  secondary_diagnosis additional_diagnosis  \
# encounter_id
# 499502                     491                  414                  250
# 447319                  250.13                   70                  794
# 309126                     786                250.6                  536
# 181183                     820                  873                 E884
# 359339                     599                  427                  414
#
#              number_diagnoses  glucose_test_result  a1c_test_result  \
# encounter_id
# 499502                      6                  NaN              NaN
# 447319                      7                 >300              NaN
# 309126                      6                  NaN              NaN
# 181183                      9                  NaN              NaN
# 359339                      9                  NaN              NaN
#
#               change_in_meds_during_hospitalization  prescribed_diabetes_meds  \
# encounter_id
# 499502                                           No                       Yes
# 447319                                           No                        No
# 309126                                           No                       Yes
# 181183                                           Ch                       Yes
# 359339                                           No                       Yes
#
#                                          medication
# encounter_id
# 499502                                ['metformin']
# 447319                                           []
# 309126                                  ['insulin']
# 181183        ['metformin', 'glyburide', 'insulin']
# 359339                                ['metformin']
#
# [5 rows x 28 columns]

# %%
train = pd.read_csv('https://raw.githubusercontent.com/Sebastiao199/Project_Group18_ML/main/train.csv', na_values=['?', ''], index_col='encounter_id')
train.head()
# Out:
#              country  patient_id             race  gender      age weight  \
# encounter_id
# 533253           USA       70110        Caucasian  Female  [70-80)    NaN
# 426224           USA    29775006  AfricanAmerican    Male  [50-60)    NaN
# 634063           USA    80729253        Caucasian  Female  [60-70)    NaN
# 890610           USA     2919042  AfricanAmerican    Male  [60-70)    NaN
# 654194           USA    84871971        Caucasian  Female  [70-80)    NaN
#
#              payer_code  outpatient_visits_in_previous_year  \
# encounter_id
# 533253              NaN                                   0
# 426224              NaN                                   0
# 634063              NaN                                   0
# 890610               MC                                   0
# 654194               HM                                   1
#
#               emergency_visits_in_previous_year  \
# encounter_id
# 533253                                        0
# 426224                                        0
# 634063                                        0
# 890610                                        0
# 654194                                        0
#
#               inpatient_visits_in_previous_year  ... secondary_diagnosis  \
# encounter_id                                     ...
# 533253                                        2  ...                 276
# 426224                                        0  ...                 785
# 634063                                        1  ...                 135
# 890610                                        1  ...                 562
# 654194                                        0  ...                 599
#
#              additional_diagnosis  number_diagnoses glucose_test_result  \
# encounter_id
# 533253                        466                 8                 NaN
# 426224                        162                 9                 NaN
# 634063                        250                 6                 NaN
# 890610                        455                 5                 NaN
# 654194                        428                 9                 NaN
#
#              a1c_test_result  change_in_meds_during_hospitalization  \
# encounter_id
# 533253                   NaN                                     No
# 426224                   NaN                                     No
# 634063                   NaN                                     Ch
# 890610                   NaN                                     No
# 654194                   NaN                                     No
#
#               prescribed_diabetes_meds                  medication  \
# encounter_id
# 533253                              No                          []
# 426224                             Yes                 ['insulin']
# 634063                             Yes  ['glimepiride', 'insulin']
# 890610                              No                          []
# 654194                              No                          []
#
#               readmitted_binary readmitted_multiclass
# encounter_id
# 533253                       No              >30 days
# 426224                       No                    No
# 634063                       No                    No
# 890610                       No                    No
# 654194                       No              >30 days
#
# [5 rows x 30 columns]

# %%
train.columns
# Out:
# Index(['country', 'patient_id', 'race', 'gender', 'age', 'weight',
#        'payer_code', 'outpatient_visits_in_previous_year',
#        'emergency_visits_in_previous_year',
#        'inpatient_visits_in_previous_year', 'admission_type',
#        'medical_specialty', 'average_pulse_bpm', 'discharge_disposition',
#        'admission_source', 'length_of_stay_in_hospital', 'number_lab_tests',
#        'non_lab_procedures', 'number_of_medications', 'primary_diagnosis',
#        'secondary_diagnosis', 'additional_diagnosis', 'number_diagnoses',
#        'glucose_test_result', 'a1c_test_result',
#        'change_in_meds_during_hospitalization', 'prescribed_diabetes_meds',
#        'medication', 'readmitted_binary', 'readmitted_multiclass'],
#       dtype='object')

# %%
test.columns
# Out:
# Index(['country', 'patient_id', 'race', 'gender', 'age', 'weight',
#        'payer_code', 'outpatient_visits_in_previous_year',
#        'emergency_visits_in_previous_year',
#        'inpatient_visits_in_previous_year', 'admission_type',
#        'medical_specialty', 'average_pulse_bpm', 'discharge_disposition',
#        'admission_source', 'length_of_stay_in_hospital', 'number_lab_tests',
#        'non_lab_procedures', 'number_of_medications', 'primary_diagnosis',
#        'secondary_diagnosis', 'additional_diagnosis', 'number_diagnoses',
#        'glucose_test_result', 'a1c_test_result',
#        'change_in_meds_during_hospitalization', 'prescribed_diabetes_meds',
#        'medication'],
#       dtype='object')

# %%
# Checking if there are duplicates on train and test

# %%
train_duplicated = train.loc[train.duplicated(), :]
train_duplicated
# Out:
# Empty DataFrame
# Columns: [country, patient_id, race, gender, age, weight, payer_code, outpatient_visits_in_previous_year, emergency_visits_in_previous_year, inpatient_visits_in_previous_year, admission_type, medical_specialty, average_pulse_bpm, discharge_disposition, admission_source, length_of_stay_in_hospital, number_lab_tests, non_lab_procedures, number_of_medications, primary_diagnosis, secondary_diagnosis, additional_diagnosis, number_diagnoses, glucose_test_result, a1c_test_result, change_in_meds_during_hospitalization, prescribed_diabetes_meds, medication, readmitted_binary, readmitted_multiclass]
# Index: []
#
# [0 rows x 30 columns]

# %%
test_duplicated = test.loc[test.duplicated(), :]
test_duplicated
# Out:
# Empty DataFrame
# Columns: [country, patient_id, race, gender, age, weight, payer_code, outpatient_visits_in_previous_year, emergency_visits_in_previous_year, inpatient_visits_in_previous_year, admission_type, medical_specialty, average_pulse_bpm, discharge_disposition, admission_source, length_of_stay_in_hospital, number_lab_tests, non_lab_procedures, number_of_medications, primary_diagnosis, secondary_diagnosis, additional_diagnosis, number_diagnoses, glucose_test_result, a1c_test_result, change_in_meds_during_hospitalization, prescribed_diabetes_meds, medication]
# Index: []
#
# [0 rows x 28 columns]

# %%
train.drop(['country','weight'], axis=1, inplace=True)

# %%
test.drop(['country','weight'], axis=1, inplace=True)

# %%
train.isna().sum()
# Out:
# patient_id                                   0
# race                                      5070
# gender                                       0
# age                                       3557
# payer_code                               28201
# outpatient_visits_in_previous_year           0
# emergency_visits_in_previous_year            0
# inpatient_visits_in_previous_year            0
# admission_type                            3706
# medical_specialty                        34922
# average_pulse_bpm                            0
# discharge_disposition                     2590
# admission_source                          4718
# length_of_stay_in_hospital                   0
# number_lab_tests                             0
# non_lab_procedures                           0
# number_of_medications                        0
# primary_diagnosis                           16
# secondary_diagnosis                        262
# additional_diagnosis                      1008
# number_diagnoses                             0
# glucose_test_result                      67548
# a1c_test_result                          59320
# change_in_meds_during_hospitalization        0
# prescribed_diabetes_meds                     0
# medication                                   0
# readmitted_binary                            0
# readmitted_multiclass                        0
# dtype: int64

# %%
test.isna().sum()
# Out:
# patient_id                                   0
# race                                      2191
# gender                                       0
# age                                       1531
# payer_code                               12055
# outpatient_visits_in_previous_year           0
# emergency_visits_in_previous_year            0
# inpatient_visits_in_previous_year            0
# admission_type                            1585
# medical_specialty                        15027
# average_pulse_bpm                            0
# discharge_disposition                     1101
# admission_source                          2063
# length_of_stay_in_hospital                   0
# number_lab_tests                             0
# non_lab_procedures                           0
# number_of_medications                        0
# primary_diagnosis                            5
# secondary_diagnosis                         96
# additional_diagnosis                       415
# number_diagnoses                             0
# glucose_test_result                      28872
# a1c_test_result                          25428
# change_in_meds_during_hospitalization        0
# prescribed_diabetes_meds                     0
# medication                                   0
# dtype: int64

# %%
train['race'].fillna('Unknown', inplace=True)
train['medical_specialty'].fillna('Unknown', inplace=True)
train['admission_source'].fillna('Unknown', inplace=True)
train['payer_code'].fillna('None', inplace=True)
train['glucose_test_result'].fillna('Not_taken', inplace=True)
train['a1c_test_result'].fillna('Not_taken', inplace=True)
train['admission_type'].fillna('Unknown', inplace=True)
train['age'].fillna('Unknown', inplace=True)
train['discharge_disposition'].fillna('Unknown', inplace=True)
train['primary_diagnosis'].fillna('Unknown', inplace=True)
train['secondary_diagnosis'].fillna('Unknown', inplace=True)
train['additional_diagnosis'].fillna('Unknown', inplace=True)

# %%
test['race'].fillna('Unknown', inplace=True)
test['medical_specialty'].fillna('Unknown', inplace=True)
test['admission_source'].fillna('Unknown', inplace=True)
test['payer_code'].fillna('None', inplace=True)
test['glucose_test_result'].fillna('Not_taken', inplace=True)
test['a1c_test_result'].fillna('Not_taken', inplace=True)
test['admission_type'].fillna('Unknown', inplace=True)
test['age'].fillna('Unknown', inplace=True)
test['discharge_disposition'].fillna('Unknown', inplace=True)
test['primary_diagnosis'].fillna('Unknown', inplace=True)
test['secondary_diagnosis'].fillna('Unknown', inplace=True)
test['additional_diagnosis'].fillna('Unknown', inplace=True)

# %%
train.isna().sum()
# Out:
# patient_id                               0
# race                                     0
# gender                                   0
# age                                      0
# payer_code                               0
# outpatient_visits_in_previous_year       0
# emergency_visits_in_previous_year        0
# inpatient_visits_in_previous_year        0
# admission_type                           0
# medical_specialty                        0
# average_pulse_bpm                        0
# discharge_disposition                    0
# admission_source                         0
# length_of_stay_in_hospital               0
# number_lab_tests                         0
# non_lab_procedures                       0
# number_of_medications                    0
# primary_diagnosis                        0
# secondary_diagnosis                      0
# additional_diagnosis                     0
# number_diagnoses                         0
# glucose_test_result                      0
# a1c_test_result                          0
# change_in_meds_during_hospitalization    0
# prescribed_diabetes_meds                 0
# medication                               0
# readmitted_binary                        0
# readmitted_multiclass                    0
# dtype: int64

# %%
test.isna().sum()
# Out:
# patient_id                               0
# race                                     0
# gender                                   0
# age                                      0
# payer_code                               0
# outpatient_visits_in_previous_year       0
# emergency_visits_in_previous_year        0
# inpatient_visits_in_previous_year        0
# admission_type                           0
# medical_specialty                        0
# average_pulse_bpm                        0
# discharge_disposition                    0
# admission_source                         0
# length_of_stay_in_hospital               0
# number_lab_tests                         0
# non_lab_procedures                       0
# number_of_medications                    0
# primary_diagnosis                        0
# secondary_diagnosis                      0
# additional_diagnosis                     0
# number_diagnoses                         0
# glucose_test_result                      0
# a1c_test_result                          0
# change_in_meds_during_hospitalization    0
# prescribed_diabetes_meds                 0
# medication                               0
# dtype: int64

# %%
new_column_names = {'outpatient_visits_in_previous_year': 'outpatient_visits', 
                    'emergency_visits_in_previous_year': 'emergency_visits',
                    'inpatient_visits_in_previous_year': 'inpatient_visits',
                    'change_in_meds_during_hospitalization': 'change_in_meds',
                    'length_of_stay_in_hospital': 'length_of_stay',
                   }
train = train.rename(columns=new_column_names)

# %%
new_column_names = {'outpatient_visits_in_previous_year': 'outpatient_visits', 
                    'emergency_visits_in_previous_year': 'emergency_visits',
                    'inpatient_visits_in_previous_year': 'inpatient_visits',
                    'change_in_meds_during_hospitalization': 'change_in_meds',
                    'length_of_stay_in_hospital': 'length_of_stay',
                   }
test = test.rename(columns=new_column_names)

# %%
train['length_of_stay']
# Out:
# encounter_id
# 533253     2
# 426224    14
# 634063     6
# 890610     6
# 654194     6
#           ..
# 660160     7
# 826429     9
# 332030     5
# 757560     2
# 459757     5
# Name: length_of_stay, Length: 71236, dtype: int64

# %%
test['length_of_stay']
# Out:
# encounter_id
# 499502     3
# 447319    10
# 309126     2
# 181183     4
# 359339     1
#           ..
# 451150     4
# 549298     2
# 327586     2
# 351214    14
# 914270     3
# Name: length_of_stay, Length: 30530, dtype: int64

# %%
def bar_charts_categorical(df, feature, target):
    cont_tab = pd.crosstab(df[feature], df[target], margins=True)
    categories = cont_tab.index[:-1]
    fig = plt.figure(figsize=(50, 10))
    # auxiliary data for 122
    obs_pct = np.array([np.divide(cont_tab.iloc[:-1, 0].values, cont_tab.iloc[:-1, 2].values), 
                        np.divide(cont_tab.iloc[:-1, 1].values, cont_tab.iloc[:-1, 2].values)])
    plt.subplot(122)
    p1 = plt.bar(categories, obs_pct[0], 0.55, color="gray")
    p2 = plt.bar(categories, obs_pct[1], 0.55, bottom=obs_pct[0], color="yellowgreen")
    plt.legend((p2[0], p1[0]), ('$y_i=1$', '$y_i=0$'))
    plt.title("Proportion bar chart")
    plt.xlabel(feature)
    plt.ylabel("$p$")
 
    #Rotacionar os rótulos do eixo x
    plt.xticks(rotation=45, ha="right")
 
    plt.show()

# %% [markdown]
# ### Race

# %%
train['race'].value_counts()
# Out:
# race
# Caucasian          50693
# AfricanAmerican    12693
# Unknown             5070
# Hispanic            1364
# Other                995
# Asian                421
# Name: count, dtype: int64

# %%
test['race'].value_counts()
# Out:
# race
# Caucasian          21617
# AfricanAmerican     5535
# Unknown             2191
# Hispanic             563
# Other                437
# Asian                187
# Name: count, dtype: int64

# %%
len(train[train['race']== '94306932'])
# Out:
# 0

# %%
len(test[test['race']== '94306932'])
# Out:
# 0

# %%
unknown = train[train['race']== 'Unknown']['patient_id'].unique()
train[train['patient_id'].isin(unknown)]
# Out:
#               patient_id       race  gender      age payer_code  \
# encounter_id
# 727104          94306932  Caucasian    Male  [70-80)         SP
# 992230          57344247    Unknown    Male  [80-90)         MC
# 353655          28219392    Unknown  Female  [60-70)         MC
# 911403          88363836    Unknown  Female  [60-70)         MC
# 811707          23388138  Caucasian  Female  [70-80)       None
# ...                  ...        ...     ...      ...        ...
# 631812          23213772    Unknown  Female  [70-80)         MC
# 714110          38516562    Unknown    Male  [80-90)         MC
# 398947          59167503    Unknown  Female  [60-70)         MC
# 537873          23904909  Caucasian  Female  [80-90)       None
# 459757          88410897  Caucasian    Male  [70-80)         BC
#
#               outpatient_visits  emergency_visits  inpatient_visits  \
# encounter_id
# 727104                        0                 0                 0
# 992230                        0                 0                 0
# 353655                        1                 0                 0
# 911403                        0                 0                 0
# 811707                        1                 1                 0
# ...                         ...               ...               ...
# 631812                        0                 0                 1
# 714110                        0                 0                 0
# 398947                        0                 0                 0
# 537873                        0                 0                 1
# 459757                        0                 0                 1
#
#              admission_type       medical_specialty  ...  secondary_diagnosis  \
# encounter_id                                         ...
# 727104               Urgent              Hematology  ...                  157
# 992230             Elective             Orthopedics  ...                  715
# 353655               Urgent        InternalMedicine  ...                 E935
# 911403            Emergency                 Unknown  ...                  414
# 811707        Not Available  Family/GeneralPractice  ...                  473
# ...                     ...                     ...  ...                  ...
# 631812             Elective        InternalMedicine  ...                  357
# 714110            Emergency                 Unknown  ...                  496
# 398947            Emergency                 Unknown  ...                  403
# 537873        Not Available        InternalMedicine  ...                  599
# 459757               Urgent         Surgery-General  ...                  250
#
#              additional_diagnosis number_diagnoses  glucose_test_result  \
# encounter_id
# 727104                        197                9            Not_taken
# 992230                        250                8            Not_taken
# 353655                        197                9            Not_taken
# 911403                        401                9            Not_taken
# 811707                      250.4                5                 Norm
# ...                           ...              ...                  ...
# 631812                        787                7            Not_taken
# 714110                        250                5            Not_taken
# 398947                        250                9            Not_taken
# 537873                        250                8                 >200
# 459757                        401                8            Not_taken
#
#               a1c_test_result  change_in_meds  prescribed_diabetes_meds  \
# encounter_id
# 727104              Not_taken              No                        No
# 992230              Not_taken              Ch                       Yes
# 353655              Not_taken              No                       Yes
# 911403                     >8              No                        No
# 811707              Not_taken              Ch                       Yes
# ...                       ...             ...                       ...
# 631812              Not_taken              Ch                       Yes
# 714110              Not_taken              No                        No
# 398947              Not_taken              Ch                       Yes
# 537873              Not_taken              Ch                       Yes
# 459757              Not_taken              Ch                       Yes
#
#                                 medication readmitted_binary  \
# encounter_id
# 727104                                  []                No
# 992230                         ['insulin']                No
# 353655                       ['glyburide']                No
# 911403                                  []                No
# 811707                         ['insulin']                No
# ...                                    ...               ...
# 631812        ['metformin', 'glimepiride']                No
# 714110                                  []                No
# 398947                         ['insulin']                No
# 537873                         ['insulin']                No
# 459757                         ['insulin']                No
#
#              readmitted_multiclass
# encounter_id
# 727104                    >30 days
# 992230                          No
# 353655                          No
# 911403                          No
# 811707                    >30 days
# ...                            ...
# 631812                          No
# 714110                    >30 days
# 398947                          No
# 537873                    >30 days
# 459757                    >30 days
#
# [7994 rows x 28 columns]

# %%
unknown = test[test['race']== 'Unknown']['patient_id'].unique()
test[test['patient_id'].isin(unknown)]
# Out:
#               patient_id       race  gender      age payer_code  \
# encounter_id
# 610450          29095002    Unknown  Female  [80-90)         MC
# 884114          15580827    Unknown  Female  [50-60)         MD
# 895020          24697071    Unknown  Female  [60-70)         MC
# 949855          66708630    Unknown  Female  [60-70)         SP
# 470398          70734564    Unknown  Female  [70-80)         MC
# ...                  ...        ...     ...      ...        ...
# 241330          41950188    Unknown    Male  Unknown         MC
# 448446          90245358    Unknown    Male  [80-90)         MC
# 382366         103896540  Caucasian    Male  [50-60)         MC
# 786267         147936164    Unknown    Male  [50-60)         SP
# 798363           3009978    Unknown    Male  [50-60)       None
#
#               outpatient_visits  emergency_visits  inpatient_visits  \
# encounter_id
# 610450                        0                 1                 0
# 884114                        0                 0                 1
# 895020                        4                 1                 1
# 949855                        0                 0                 0
# 470398                        0                 0                 0
# ...                         ...               ...               ...
# 241330                        0                 0                 0
# 448446                        1                 1                 2
# 382366                        0                 0                 1
# 786267                        0                 0                 0
# 798363                        0                 0                 0
#
#              admission_type       medical_specialty  ...  \
# encounter_id                                         ...
# 610450        Not Available                 Unknown  ...
# 884114               Urgent  Family/GeneralPractice  ...
# 895020             Elective              Nephrology  ...
# 949855            Emergency                 Unknown  ...
# 470398            Emergency                 Unknown  ...
# ...                     ...                     ...  ...
# 241330            Emergency                 Unknown  ...
# 448446            Emergency                 Unknown  ...
# 382366               Urgent  Family/GeneralPractice  ...
# 786267            Emergency                 Unknown  ...
# 798363             Elective                 Unknown  ...
#
#               number_of_medications primary_diagnosis secondary_diagnosis  \
# encounter_id
# 610450                           11                38                 599
# 884114                           20               487                 491
# 895020                           21               996                 403
# 949855                           16               482                 584
# 470398                           19               414                 411
# ...                             ...               ...                 ...
# 241330                           15               491                 486
# 448446                           13               599                 496
# 382366                            7               420                 996
# 786267                           64               414                 357
# 798363                           11               682                 428
#
#               additional_diagnosis  number_diagnoses  glucose_test_result  \
# encounter_id
# 610450                         428                 5                 Norm
# 884114                      250.02                 5            Not_taken
# 895020                       250.4                 4            Not_taken
# 949855                         403                 9            Not_taken
# 470398                         496                 9            Not_taken
# ...                            ...               ...                  ...
# 241330                         427                 8            Not_taken
# 448446                         585                 9            Not_taken
# 382366                         403                 5            Not_taken
# 786267                       250.6                 9            Not_taken
# 798363                         425                 4            Not_taken
#
#               a1c_test_result change_in_meds prescribed_diabetes_meds  \
# encounter_id
# 610450              Not_taken             Ch                      Yes
# 884114              Not_taken             Ch                      Yes
# 895020              Not_taken             Ch                      Yes
# 949855                     >8             No                      Yes
# 470398              Not_taken             Ch                      Yes
# ...                       ...            ...                      ...
# 241330              Not_taken             No                      Yes
# 448446              Not_taken             No                       No
# 382366              Not_taken             No                       No
# 786267              Not_taken             Ch                      Yes
# 798363              Not_taken             No                       No
#
#                                              medication
# encounter_id
# 610450                      ['pioglitazone', 'insulin']
# 884114        ['metformin', 'rosiglitazone', 'insulin']
# 895020                                      ['insulin']
# 949855                                    ['glipizide']
# 470398                         ['metformin', 'insulin']
# ...                                                 ...
# 241330                                    ['metformin']
# 448446                                               []
# 382366                                               []
# 786267                                      ['insulin']
# 798363                                               []
#
# [2731 rows x 26 columns]

# %%
train[train['patient_id']== 23904909]
# Out:
#               patient_id       race  gender      age payer_code  \
# encounter_id
# 282627          23904909    Unknown  Female  [80-90)       None
# 537873          23904909  Caucasian  Female  [80-90)       None
#
#               outpatient_visits  emergency_visits  inpatient_visits  \
# encounter_id
# 282627                        0                 0                 2
# 537873                        0                 0                 1
#
#              admission_type       medical_specialty  ...  secondary_diagnosis  \
# encounter_id                                         ...
# 282627        Not Available  Family/GeneralPractice  ...                  599
# 537873        Not Available        InternalMedicine  ...                  599
#
#              additional_diagnosis number_diagnoses  glucose_test_result  \
# encounter_id
# 282627                        413                7                 >200
# 537873                        250                8                 >200
#
#               a1c_test_result  change_in_meds  prescribed_diabetes_meds  \
# encounter_id
# 282627              Not_taken              Ch                       Yes
# 537873              Not_taken              Ch                       Yes
#
#                medication readmitted_binary readmitted_multiclass
# encounter_id
# 282627        ['insulin']                No                    No
# 537873        ['insulin']                No              >30 days
#
# [2 rows x 28 columns]

# %%
test[test['patient_id']== 23904909]
# Out:
#               patient_id       race  gender      age payer_code  \
# encounter_id
# 272826          23904909  Caucasian  Female  [80-90)       None
#
#               outpatient_visits  emergency_visits  inpatient_visits  \
# encounter_id
# 272826                        0                 0                 0
#
#              admission_type medical_specialty  ...  number_of_medications  \
# encounter_id                                   ...
# 272826        Not Available  InternalMedicine  ...                      7
#
#              primary_diagnosis secondary_diagnosis  additional_diagnosis  \
# encounter_id
# 272826                     728                 294                   414
#
#               number_diagnoses  glucose_test_result  a1c_test_result  \
# encounter_id
# 272826                       7                 Norm        Not_taken
#
#              change_in_meds prescribed_diabetes_meds   medication
# encounter_id
# 272826                   No                      Yes  ['insulin']
#
# [1 rows x 26 columns]

# %%
unknown = train[train['race']== 'Unknown']['patient_id'].unique()

known_race = train[train['patient_id'].isin(unknown) & train['race']!= 'Unknown']

# %%
unknown = test[test['race']== 'Unknown']['patient_id'].unique()

known_race = test[test['patient_id'].isin(unknown) & test['race']!= 'Unknown']

# %%
train[train['race']=='Unknown'].shape
# Out:
# (5070, 28)

# %%
test[test['race']=='Unknown'].shape
# Out:
# (2191, 26)

# %%
def fill_race(df):
    for i, row in df.iterrows():
        if row['race'] == 'Unknown':
            # Check if there are any other rows with the same 'person_id' and 'race' not equal to 'Unknown'
            other_rows = df[(df['patient_id'] == row['patient_id']) & (df['race'] != 'Unknown')]
            if not other_rows.empty:
                # If such a row is found, replace the 'race' of the current row with the 'race' of the found row
                df.at[i, 'race'] = other_rows.iloc[0]['race']
    return df

fill_race(train)
# Out:
#               patient_id             race  gender      age payer_code  \
# encounter_id
# 533253             70110        Caucasian  Female  [70-80)       None
# 426224          29775006  AfricanAmerican    Male  [50-60)       None
# 634063          80729253        Caucasian  Female  [60-70)       None
# 890610           2919042  AfricanAmerican    Male  [60-70)         MC
# 654194          84871971        Caucasian  Female  [70-80)         HM
# ...                  ...              ...     ...      ...        ...
# 660160          24531381  AfricanAmerican  Female  [80-90)         MC
# 826429           4663818  AfricanAmerican  Female  [70-80)       None
# 332030          23397147        Caucasian  Female  [60-70)       None
# 757560          52161750        Caucasian    Male  [60-70)         BC
# 459757          88410897        Caucasian    Male  [70-80)         BC
#
#               outpatient_visits  emergency_visits  inpatient_visits  \
# encounter_id
# 533253                        0                 0                 2
# 426224                        0                 0                 0
# 634063                        0                 0                 1
# 890610                        0                 0                 1
# 654194                        1                 0                 0
# ...                         ...               ...               ...
# 660160                        0                 1                 0
# 826429                        0                 0                 0
# 332030                        0                 2                 2
# 757560                        0                 0                 2
# 459757                        0                 0                 1
#
#              admission_type       medical_specialty  ...  secondary_diagnosis  \
# encounter_id                                         ...
# 533253            Emergency  Family/GeneralPractice  ...                  276
# 426224            Emergency                 Unknown  ...                  785
# 634063              Unknown  Family/GeneralPractice  ...                  135
# 890610            Emergency        InternalMedicine  ...                  562
# 654194             Elective                 Unknown  ...                  599
# ...                     ...                     ...  ...                  ...
# 660160             Elective        InternalMedicine  ...                  786
# 826429               Urgent                 Unknown  ...                  197
# 332030              Unknown                 Unknown  ...                  491
# 757560            Emergency        Emergency/Trauma  ...                  157
# 459757               Urgent         Surgery-General  ...                  250
#
#              additional_diagnosis number_diagnoses  glucose_test_result  \
# encounter_id
# 533253                        466                8            Not_taken
# 426224                        162                9            Not_taken
# 634063                        250                6            Not_taken
# 890610                        455                5            Not_taken
# 654194                        428                9            Not_taken
# ...                           ...              ...                  ...
# 660160                        250                9            Not_taken
# 826429                        V66                6            Not_taken
# 332030                        276                9                 >300
# 757560                      250.8                5            Not_taken
# 459757                        401                8            Not_taken
#
#               a1c_test_result  change_in_meds  prescribed_diabetes_meds  \
# encounter_id
# 533253              Not_taken              No                        No
# 426224              Not_taken              No                       Yes
# 634063              Not_taken              Ch                       Yes
# 890610              Not_taken              No                        No
# 654194              Not_taken              No                        No
# ...                       ...             ...                       ...
# 660160                     >7              Ch                       Yes
# 826429                     >7              Ch                       Yes
# 332030              Not_taken              Ch                       Yes
# 757560              Not_taken              Ch                       Yes
# 459757              Not_taken              Ch                       Yes
#
#                                          medication readmitted_binary  \
# encounter_id
# 533253                                           []                No
# 426224                                  ['insulin']                No
# 634063                   ['glimepiride', 'insulin']                No
# 890610                                           []                No
# 654194                                           []                No
# ...                                             ...               ...
# 660160        ['metformin', 'glyburide', 'insulin']                No
# 826429                   ['metformin', 'glyburide']                No
# 332030                     ['glyburide', 'insulin']               Yes
# 757560                     ['glyburide', 'insulin']                No
# 459757                                  ['insulin']                No
#
#              readmitted_multiclass
# encounter_id
# 533253                    >30 days
# 426224                          No
# 634063                          No
# 890610                          No
# 654194                    >30 days
# ...                            ...
# 660160                          No
# 826429                          No
# 332030                    <30 days
# 757560                          No
# 459757                    >30 days
#
# [71236 rows x 28 columns]

# %%
fill_race(test)
# Out:
#               patient_id             race  gender      age payer_code  \
# encounter_id
# 499502         103232799        Caucasian    Male  [80-90)         HM
# 447319          93395304        Caucasian    Male  [20-30)         HM
# 309126           6281586  AfricanAmerican    Male  [30-40)       None
# 181183          67381308        Caucasian    Male  [50-60)         BC
# 359339          71670204        Caucasian    Male  [60-70)       None
# ...                  ...              ...     ...      ...        ...
# 451150          85707450        Caucasian    Male  [70-80)         HM
# 549298            328887        Caucasian    Male  [60-70)       None
# 327586          21915459        Caucasian  Female  [80-90)       None
# 351214          17823546        Caucasian    Male  Unknown         MC
# 914270          42043239        Caucasian  Female  [60-70)         MD
#
#               outpatient_visits  emergency_visits  inpatient_visits  \
# encounter_id
# 499502                        0                 0                 0
# 447319                        0                 0                 1
# 309126                        0                 0                 0
# 181183                        0                 0                 0
# 359339                        0                 0                 0
# ...                         ...               ...               ...
# 451150                        0                 0                 0
# 549298                        0                 0                 4
# 327586                        0                 0                 0
# 351214                        0                 0                 0
# 914270                        0                 0                 1
#
#              admission_type       medical_specialty  ...  \
# encounter_id                                         ...
# 499502            Emergency                 Unknown  ...
# 447319            Emergency                 Unknown  ...
# 309126            Emergency             Pulmonology  ...
# 181183        Not Available                 Unknown  ...
# 359339            Emergency        InternalMedicine  ...
# ...                     ...                     ...  ...
# 451150            Emergency                 Unknown  ...
# 549298            Emergency  Family/GeneralPractice  ...
# 327586            Emergency              Nephrology  ...
# 351214               Urgent        InternalMedicine  ...
# 914270             Elective                 Unknown  ...
#
#               number_of_medications primary_diagnosis secondary_diagnosis  \
# encounter_id
# 499502                           14               491                 414
# 447319                            7            250.13                  70
# 309126                           12               786               250.6
# 181183                           16               820                 873
# 359339                           10               599                 427
# ...                             ...               ...                 ...
# 451150                           11               584                 276
# 549298                           19               428              250.83
# 327586                           22               996                 403
# 351214                           21               153                 780
# 914270                           11               486             Unknown
#
#               additional_diagnosis  number_diagnoses  glucose_test_result  \
# encounter_id
# 499502                         250                 6            Not_taken
# 447319                         794                 7                 >300
# 309126                         536                 6            Not_taken
# 181183                        E884                 9            Not_taken
# 359339                         414                 9            Not_taken
# ...                            ...               ...                  ...
# 451150                         276                 9            Not_taken
# 549298                         276                 9            Not_taken
# 327586                         250                 6            Not_taken
# 351214                         285                 5            Not_taken
# 914270                         428                 8            Not_taken
#
#               a1c_test_result change_in_meds prescribed_diabetes_meds  \
# encounter_id
# 499502              Not_taken             No                      Yes
# 447319              Not_taken             No                       No
# 309126              Not_taken             No                      Yes
# 181183              Not_taken             Ch                      Yes
# 359339              Not_taken             No                      Yes
# ...                       ...            ...                      ...
# 451150              Not_taken             No                       No
# 549298              Not_taken             No                      Yes
# 327586              Not_taken             No                      Yes
# 351214                     >7             Ch                      Yes
# 914270              Not_taken             No                      Yes
#
#                                             medication
# encounter_id
# 499502                                   ['metformin']
# 447319                                              []
# 309126                                     ['insulin']
# 181183           ['metformin', 'glyburide', 'insulin']
# 359339                                   ['metformin']
# ...                                                ...
# 451150                                              []
# 549298                                     ['insulin']
# 327586                                     ['insulin']
# 351214        ['glipizide', 'pioglitazone', 'insulin']
# 914270                                ['pioglitazone']
#
# [30530 rows x 26 columns]

# %%
train[train['race']=='Unknown'].shape
# Out:
# (3648, 28)

# %%
test[test['race']=='Unknown'].shape
# Out:
# (1828, 26)

# %%
train[train['patient_id']== 23904909]
# Out:
#               patient_id       race  gender      age payer_code  \
# encounter_id
# 282627          23904909  Caucasian  Female  [80-90)       None
# 537873          23904909  Caucasian  Female  [80-90)       None
#
#               outpatient_visits  emergency_visits  inpatient_visits  \
# encounter_id
# 282627                        0                 0                 2
# 537873                        0                 0                 1
#
#              admission_type       medical_specialty  ...  secondary_diagnosis  \
# encounter_id                                         ...
# 282627        Not Available  Family/GeneralPractice  ...                  599
# 537873        Not Available        InternalMedicine  ...                  599
#
#              additional_diagnosis number_diagnoses  glucose_test_result  \
# encounter_id
# 282627                        413                7                 >200
# 537873                        250                8                 >200
#
#               a1c_test_result  change_in_meds  prescribed_diabetes_meds  \
# encounter_id
# 282627              Not_taken              Ch                       Yes
# 537873              Not_taken              Ch                       Yes
#
#                medication readmitted_binary readmitted_multiclass
# encounter_id
# 282627        ['insulin']                No                    No
# 537873        ['insulin']                No              >30 days
#
# [2 rows x 28 columns]

# %%
test[test['patient_id']== 23904909]
# Out:
#               patient_id       race  gender      age payer_code  \
# encounter_id
# 272826          23904909  Caucasian  Female  [80-90)       None
#
#               outpatient_visits  emergency_visits  inpatient_visits  \
# encounter_id
# 272826                        0                 0                 0
#
#              admission_type medical_specialty  ...  number_of_medications  \
# encounter_id                                   ...
# 272826        Not Available  InternalMedicine  ...                      7
#
#              primary_diagnosis secondary_diagnosis  additional_diagnosis  \
# encounter_id
# 272826                     728                 294                   414
#
#               number_diagnoses  glucose_test_result  a1c_test_result  \
# encounter_id
# 272826                       7                 Norm        Not_taken
#
#              change_in_meds prescribed_diabetes_meds   medication
# encounter_id
# 272826                   No                      Yes  ['insulin']
#
# [1 rows x 26 columns]

# %%
bar_charts_categorical(train, "race", "readmitted_binary")

# %%
train['race'].value_counts()
# Out:
# race
# Caucasian          51779
# AfricanAmerican    12977
# Unknown             3648
# Hispanic            1394
# Other               1013
# Asian                425
# Name: count, dtype: int64

# %%
test['race'].value_counts()
# Out:
# race
# Caucasian          21880
# AfricanAmerican     5618
# Unknown             1828
# Hispanic             570
# Other                443
# Asian                191
# Name: count, dtype: int64

# %%
train['race_caucasian'] = train['race'].apply(lambda x: 1 if x == 'Caucasian' else 0)

# %%
test['race_caucasian'] = test['race'].apply(lambda x: 1 if x == 'Caucasian' else 0)

# %%
train.drop(['race'], axis=1, inplace=True)

# %%
test.drop(['race'], axis=1, inplace=True)

# %%
train['race_caucasian'].value_counts()
# Out:
# race_caucasian
# 1    51779
# 0    19457
# Name: count, dtype: int64

# %%
test['race_caucasian'].value_counts()
# Out:
# race_caucasian
# 1    21880
# 0     8650
# Name: count, dtype: int64

# %%
bar_charts_categorical(train, "race_caucasian", "readmitted_binary")

# %% [markdown]
# ### Medication

# %%
train['medication'].value_counts(normalize=True)
# Out:
# medication
# ['insulin']                                                       0.304832
# []                                                                0.229463
# ['metformin']                                                     0.044247
# ['metformin', 'insulin']                                          0.042689
# ['glipizide']                                                     0.038281
#                                                                     ...
# ['pioglitazone', 'acarbose', 'insulin', 'glyburide-metformin']    0.000014
# ['glimepiride', 'rosiglitazone', 'acarbose']                      0.000014
# ['glipizide', 'pioglitazone', 'acarbose', 'insulin']              0.000014
# ['metformin', 'glyburide', 'acarbose', 'insulin']                 0.000014
# ['glimepiride', 'rosiglitazone', 'miglitol', 'insulin']           0.000014
# Name: proportion, Length: 303, dtype: float64

# %%
test['medication'].value_counts(normalize=True)
# Out:
# medication
# ['insulin']                                                             0.302981
# []                                                                      0.231150
# ['metformin']                                                           0.043629
# ['metformin', 'insulin']                                                0.042614
# ['glipizide']                                                           0.037373
#                                                                           ...
# ['pioglitazone', 'tolazamide', 'insulin']                               0.000033
# ['metformin', 'glipizide', 'glyburide', 'pioglitazone', 'insulin']      0.000033
# ['nateglinide', 'rosiglitazone', 'acarbose']                            0.000033
# ['metformin', 'nateglinide', 'glipizide', 'pioglitazone', 'insulin']    0.000033
# ['rosiglitazone', 'acarbose', 'insulin']                                0.000033
# Name: proportion, Length: 232, dtype: float64

# %%
train['medication'] = train['medication'].str.replace('[]', 'no_medication')

# %%
test['medication'] = test['medication'].str.replace('[]', 'no_medication')

# %%
train['number_generic_medications'] = train['medication'].apply(lambda x: 0 if x=='no_medication' else len((x.replace("[", "").replace("]", "")).split(',')))

# %%
test['number_generic_medications'] = test['medication'].apply(lambda x: 0 if x=='no_medication' else len((x.replace("[", "").replace("]", "")).split(',')))

# %%
train['number_generic_medications'].value_counts()
# Out:
# number_generic_medications
# 1    33182
# 0    16346
# 2    15289
# 3     5446
# 4      929
# 5       41
# 6        3
# Name: count, dtype: int64

# %%
# Assuming df is your DataFrame and 'medication' is your column
train['medication'] = train['medication'].apply(lambda x: [i.strip().strip('\'"') for i in x.strip('[]').split(',')])

# Get the list of unique medications
medications = set(x for l in train['medication'] for x in l)

# Create new columns for each medication
for med in medications:
    train[med] = train['medication'].apply(lambda x: 1 if med in x else 0)

# %%
# Assuming df is your DataFrame and 'medication' is your column
test['medication'] = test['medication'].apply(lambda x: [i.strip().strip('\'"') for i in x.strip('[]').split(',')])

# Get the list of unique medications
medications = set(x for l in test['medication'] for x in l)

# Create new columns for each medication
for med in medications:
    test[med] = test['medication'].apply(lambda x: 1 if med in x else 0)

# %%
train['Sulfonylureas'] = train['glipizide']+train['glyburide']+train['tolbutamide']+train['acetohexamide']+train['chlorpropamide']
+train['glimepiride']+train['tolazamide']
train['Meglitinides'] = train['repaglinide'] + train['nateglinide']
train['Thiazolidinediones'] = train['pioglitazone'] + train['rosiglitazone'] + train['troglitazone']
train['Alpha_Glucosidase_Inhibitors'] = train['acarbose'] + train['miglitol']
train['Combination_Medications'] = train['glimepiride-pioglitazone']+train['glyburide-metformin']+train['metformin-pioglitazone']
+train['glipizide-metformin']+train['metformin-rosiglitazone']
# Out:
# encounter_id
# 533253    0
# 426224    0
# 634063    0
# 890610    0
# 654194    0
#          ..
# 660160    0
# 826429    0
# 332030    0
# 757560    0
# 459757    0
# Length: 71236, dtype: int64

# %%
# Tirei alguns medications pq não havia no test
test['Sulfonylureas'] = test['glipizide'] + test['glyburide'] + test['tolbutamide'] + test['chlorpropamide'] + test['glimepiride'] + test['tolazamide']
test['Meglitinides'] = test['repaglinide'] + test['nateglinide']
test['Thiazolidinediones'] = test['pioglitazone'] + test['rosiglitazone'] + test['troglitazone']
test['Alpha_Glucosidase_Inhibitors'] = test['acarbose'] + test['miglitol']
test['Combination_Medications'] = test['glipizide-metformin'] + test['metformin-rosiglitazone']

# %%
train.drop(['tolazamide', 'miglitol', 'repaglinide',
'nateglinide', 'glimepiride-pioglitazone', 'glipizide', 'pioglitazone',
'glyburide', 'acetohexamide', 'tolbutamide',
'acarbose', 'glyburide-metformin',
'metformin-pioglitazone', 'glipizide-metformin',
'metformin-rosiglitazone', 'chlorpropamide', 'rosiglitazone',
'troglitazone', 'glimepiride'], axis=1, inplace=True)

# %%
# Tirei alguns medications pq não havia no test
test.drop(['tolazamide', 'miglitol', 'repaglinide',
'nateglinide', 'glipizide', 'pioglitazone',
'glyburide', 'tolbutamide',
'acarbose', 'glyburide-metformin',
'glipizide-metformin',
'metformin-rosiglitazone', 'chlorpropamide', 'rosiglitazone',
'troglitazone', 'glimepiride'], axis=1, inplace=True)

# %%
medication_columns = ['Sulfonylureas','Meglitinides','Thiazolidinediones','Alpha_Glucosidase_Inhibitors',
                     'Combination_Medications','insulin','no_medication','metformin']
for col in medication_columns:
    print(train[col].value_counts())
    print('')
# Out:
# Sulfonylureas
# 0    54890
# 1    16194
# 2      152
# Name: count, dtype: int64
#
# Meglitinides
# 0    69686
# 1     1544
# 2        6
# Name: count, dtype: int64
#
# Thiazolidinediones
# 0    61699
# 1     9507
# 2       30
# Name: count, dtype: int64
#
# Alpha_Glucosidase_Inhibitors
# 0    71003
# 1      233
# Name: count, dtype: int64
#
# Combination_Medications
# 0    70737
# 1      499
# Name: count, dtype: int64
#
# insulin
# 1    38105
# 0    33131
# Name: count, dtype: int64
#
# no_medication
# 0    54890
# 1    16346
# Name: count, dtype: int64
#
# metformin
# 0    57271
# 1    13965
# Name: count, dtype: int64

# %%
for col in medication_columns:
    bar_charts_categorical(train, col, "readmitted_binary")

# %%
bar_charts_categorical(train, "number_generic_medications", "readmitted_binary")

# %%
# pd.set_option('display.max_colwidth', None)
train[train['number_generic_medications']==5]['medication']
# Out:
# encounter_id
# 552573    [metformin, glipizide, glyburide, pioglitazone...
# 123846    [metformin, repaglinide, glipizide, acarbose, ...
# 582550    [metformin, glimepiride, glyburide, rosiglitaz...
# 779718    [metformin, glimepiride, glipizide, pioglitazo...
# 933380    [metformin, repaglinide, glipizide, pioglitazo...
# 447982    [metformin, glyburide, pioglitazone, insulin, ...
# 692561    [metformin, glimepiride, glipizide, pioglitazo...
# 589216    [metformin, repaglinide, glimepiride, rosiglit...
# 999052    [metformin, glimepiride, glyburide, pioglitazo...
# 451372    [metformin, repaglinide, glimepiride, pioglita...
# 997560    [metformin, glimepiride, glyburide, pioglitazo...
# 994513    [metformin, glipizide, glyburide, pioglitazone...
# 162953    [metformin, glimepiride, glipizide, glyburide,...
# 531851    [metformin, glipizide, pioglitazone, rosiglita...
# 448305    [metformin, glipizide, glyburide, rosiglitazon...
# 456910    [metformin, glimepiride, glyburide, rosiglitaz...
# 607305    [metformin, glipizide, glyburide, rosiglitazon...
# 949581    [metformin, nateglinide, glipizide, pioglitazo...
# 245459    [metformin, glimepiride, glyburide, rosiglitaz...
# 235867    [metformin, glipizide, pioglitazone, acarbose,...
# 682270    [metformin, glipizide, glyburide, pioglitazone...
# 957372    [metformin, repaglinide, glyburide, rosiglitaz...
# 949034    [metformin, repaglinide, glimepiride, pioglita...
# 410008    [metformin, repaglinide, glipizide, rosiglitaz...
# 476361    [metformin, glimepiride, glipizide, rosiglitaz...
# 346271    [metformin, glipizide, glyburide, pioglitazone...
# 800891    [metformin, glipizide, rosiglitazone, acarbose...
# 982268    [metformin, repaglinide, glipizide, rosiglitaz...
# 126332    [metformin, glipizide, glyburide, rosiglitazon...
# 692552    [metformin, glyburide, pioglitazone, acarbose,...
# 695395    [metformin, glipizide, glyburide, rosiglitazon...
# 472794    [metformin, glipizide, pioglitazone, rosiglita...
# 247216    [metformin, repaglinide, glyburide, pioglitazo...
# 731504    [metformin, glyburide, pioglitazone, rosiglita...
# 357162    [metformin, glimepiride, glipizide, pioglitazo...
# 886759    [metformin, repaglinide, glipizide, acarbose, ...
# 398539    [metformin, glimepiride, pioglitazone, insulin...
# 826243    [metformin, glipizide, glyburide, pioglitazone...
# 805062    [metformin, glipizide, glyburide, pioglitazone...
# 986521    [metformin, nateglinide, glimepiride, pioglita...
# 857791    [metformin, glipizide, glyburide, pioglitazone...
# Name: medication, dtype: object

# %%
# pd.set_option('display.max_colwidth', None)
test[test['number_generic_medications']==5]['medication']
# Out:
# encounter_id
# 990126    [metformin, glipizide, pioglitazone, rosiglita...
# 252924    [metformin, nateglinide, glimepiride, glipizid...
# 707897    [metformin, repaglinide, glyburide, pioglitazo...
# 915560    [metformin, glipizide, glyburide, rosiglitazon...
# 353917    [metformin, glimepiride, pioglitazone, acarbos...
# 965253    [metformin, nateglinide, glipizide, pioglitazo...
# 763262    [metformin, glipizide, glyburide, pioglitazone...
# 658521    [metformin, repaglinide, glipizide, pioglitazo...
# 821858    [metformin, glyburide, pioglitazone, rosiglita...
# 410586    [metformin, repaglinide, glipizide, rosiglitaz...
# 954243    [metformin, glimepiride, glipizide, rosiglitaz...
# 319387    [metformin, glipizide, glyburide, rosiglitazon...
# 991505    [metformin, repaglinide, rosiglitazone, acarbo...
# 760667    [metformin, glimepiride, rosiglitazone, miglit...
# 440154    [metformin, glipizide, glyburide, rosiglitazon...
# 413789    [metformin, glyburide, pioglitazone, acarbose,...
# 182499    [metformin, glimepiride, glyburide, pioglitazo...
# Name: medication, dtype: object

# %%
# pd.set_option('display.max_colwidth', None)
train[train['number_generic_medications']==6][['medication','readmitted_binary']]
# Out:
#                                                      medication  \
# encounter_id
# 308794        [metformin, nateglinide, glipizide, rosiglitaz...
# 837132        [metformin, nateglinide, glipizide, glyburide,...
# 890037        [metformin, glimepiride, glipizide, pioglitazo...
#
#              readmitted_binary
# encounter_id
# 308794                     Yes
# 837132                     Yes
# 890037                      No

# %%
bar_charts_categorical(train, "age", "readmitted_binary")

# %%
data = train['age']
df = pd.DataFrame(data)

# Extract the lower and upper age values as separate columns
df[['Lower_Age', 'Upper_Age']] = df['age'].str.extract(r'\[(\d+)-(\d+)\)')

df['Lower_Age'] = pd.to_numeric(df['Lower_Age'], errors='coerce', downcast='integer')
df['Upper_Age'] = pd.to_numeric(df['Upper_Age'], errors='coerce', downcast='integer')


df['Midpoint_Age'] = average_age = np.where(df['Lower_Age'].notna() & df['Upper_Age'].notna(),
                       (df['Lower_Age'] + df['Upper_Age']) / 2,
                       np.nan)
train['Midpoint_Age'] = df['Midpoint_Age']
train.drop('age', axis=1, inplace=True)

# %%
data = test['age']
df = pd.DataFrame(data)

# Extract the lower and upper age values as separate columns
df[['Lower_Age', 'Upper_Age']] = df['age'].str.extract(r'\[(\d+)-(\d+)\)')

df['Lower_Age'] = pd.to_numeric(df['Lower_Age'], errors='coerce', downcast='integer')
df['Upper_Age'] = pd.to_numeric(df['Upper_Age'], errors='coerce', downcast='integer')

# Calculate the midpoint age
df['Midpoint_Age'] = np.where(df['Lower_Age'].notna() & df['Upper_Age'].notna(),
                              (df['Lower_Age'] + df['Upper_Age']) / 2,
                              np.nan)
test['Midpoint_Age'] = df['Midpoint_Age']
test.drop('age', axis=1, inplace=True)

# %%
train['Midpoint_Age'].fillna('Unknown', inplace=True)

# %%
test['Midpoint_Age'].fillna('Unknown', inplace=True)

# %%
train[train['Midpoint_Age']=='Unknown'].shape[0]
# Out:
# 3557

# %%
test[test['Midpoint_Age']=='Unknown'].shape[0]
# Out:
# 1531

# %%
def fill_age(df):
    for i, row in df.iterrows():
        if row['Midpoint_Age'] == 'Unknown':
            # Check if there are any other rows with the same 'person_id' and 'race' not equal to 'Unknown'
            other_rows = df[(df['patient_id'] == row['patient_id']) & (df['Midpoint_Age'] != 'Unknown')]
            if not other_rows.empty:
                # If such a row is found, replace the 'race' of the current row with the 'race' of the found row
                df.at[i, 'Midpoint_Age'] = other_rows.iloc[0]['Midpoint_Age']
    return df

fill_age(train)
# Out:
#               patient_id  gender payer_code  outpatient_visits  \
# encounter_id
# 533253             70110  Female       None                  0
# 426224          29775006    Male       None                  0
# 634063          80729253  Female       None                  0
# 890610           2919042    Male         MC                  0
# 654194          84871971  Female         HM                  1
# ...                  ...     ...        ...                ...
# 660160          24531381  Female         MC                  0
# 826429           4663818  Female       None                  0
# 332030          23397147  Female       None                  0
# 757560          52161750    Male         BC                  0
# 459757          88410897    Male         BC                  0
#
#               emergency_visits  inpatient_visits admission_type  \
# encounter_id
# 533253                       0                 2      Emergency
# 426224                       0                 0      Emergency
# 634063                       0                 1        Unknown
# 890610                       0                 1      Emergency
# 654194                       0                 0       Elective
# ...                        ...               ...            ...
# 660160                       1                 0       Elective
# 826429                       0                 0         Urgent
# 332030                       2                 2        Unknown
# 757560                       0                 2      Emergency
# 459757                       0                 1         Urgent
#
#                    medical_specialty  average_pulse_bpm  \
# encounter_id
# 533253        Family/GeneralPractice                127
# 426224                       Unknown                128
# 634063        Family/GeneralPractice                 94
# 890610              InternalMedicine                 81
# 654194                       Unknown                126
# ...                              ...                ...
# 660160              InternalMedicine                 90
# 826429                       Unknown                 98
# 332030                       Unknown                137
# 757560              Emergency/Trauma                123
# 459757               Surgery-General                 62
#
#                                           discharge_disposition  ...  \
# encounter_id                                                     ...
# 533253                                       Discharged to home  ...
# 426224        Discharged/transferred to a federal health car...  ...
# 634063                                       Discharged to home  ...
# 890610                                       Discharged to home  ...
# 654194        Discharged/transferred to home with home healt...  ...
# ...                                                         ...  ...
# 660160                                       Discharged to home  ...
# 826429                                                  Unknown  ...
# 332030                                               Not Mapped  ...
# 757560                            Discharged/transferred to SNF  ...
# 459757                                       Discharged to home  ...
#
#              number_generic_medications  metformin  no_medication  insulin  \
# encounter_id
# 533253                                0          0              1        0
# 426224                                1          0              0        1
# 634063                                2          0              0        1
# 890610                                0          0              1        0
# 654194                                0          0              1        0
# ...                                 ...        ...            ...      ...
# 660160                                3          1              0        1
# 826429                                2          1              0        0
# 332030                                2          0              0        1
# 757560                                2          0              0        1
# 459757                                1          0              0        1
#
#               Sulfonylureas Meglitinides Thiazolidinediones  \
# encounter_id
# 533253                    0            0                  0
# 426224                    0            0                  0
# 634063                    0            0                  0
# 890610                    0            0                  0
# 654194                    0            0                  0
# ...                     ...          ...                ...
# 660160                    1            0                  0
# 826429                    1            0                  0
# 332030                    1            0                  0
# 757560                    1            0                  0
# 459757                    0            0                  0
#
#              Alpha_Glucosidase_Inhibitors  Combination_Medications  \
# encounter_id
# 533253                                  0                        0
# 426224                                  0                        0
# 634063                                  0                        0
# 890610                                  0                        0
# 654194                                  0                        0
# ...                                   ...                      ...
# 660160                                  0                        0
# 826429                                  0                        0
# 332030                                  0                        0
# 757560                                  0                        0
# 459757                                  0                        0
#
#              Midpoint_Age
# encounter_id
# 533253               75.0
# 426224               55.0
# 634063               65.0
# 890610               65.0
# 654194               75.0
# ...                   ...
# 660160               85.0
# 826429               75.0
# 332030               65.0
# 757560               65.0
# 459757               75.0
#
# [71236 rows x 37 columns]

# %%
fill_age(test)
# Out:
#               patient_id  gender payer_code  outpatient_visits  \
# encounter_id
# 499502         103232799    Male         HM                  0
# 447319          93395304    Male         HM                  0
# 309126           6281586    Male       None                  0
# 181183          67381308    Male         BC                  0
# 359339          71670204    Male       None                  0
# ...                  ...     ...        ...                ...
# 451150          85707450    Male         HM                  0
# 549298            328887    Male       None                  0
# 327586          21915459  Female       None                  0
# 351214          17823546    Male         MC                  0
# 914270          42043239  Female         MD                  0
#
#               emergency_visits  inpatient_visits admission_type  \
# encounter_id
# 499502                       0                 0      Emergency
# 447319                       0                 1      Emergency
# 309126                       0                 0      Emergency
# 181183                       0                 0  Not Available
# 359339                       0                 0      Emergency
# ...                        ...               ...            ...
# 451150                       0                 0      Emergency
# 549298                       0                 4      Emergency
# 327586                       0                 0      Emergency
# 351214                       0                 0         Urgent
# 914270                       0                 1       Elective
#
#                    medical_specialty  average_pulse_bpm  \
# encounter_id
# 499502                       Unknown                139
# 447319                       Unknown                103
# 309126                   Pulmonology                 99
# 181183                       Unknown                136
# 359339              InternalMedicine                137
# ...                              ...                ...
# 451150                       Unknown                133
# 549298        Family/GeneralPractice                 62
# 327586                    Nephrology                121
# 351214              InternalMedicine                136
# 914270                       Unknown                128
#
#                       discharge_disposition  ... number_generic_medications  \
# encounter_id                                 ...
# 499502                   Discharged to home  ...                          1
# 447319                   Discharged to home  ...                          0
# 309126                   Discharged to home  ...                          1
# 181183                   Discharged to home  ...                          3
# 359339                   Discharged to home  ...                          1
# ...                                     ...  ...                        ...
# 451150        Discharged/transferred to SNF  ...                          0
# 549298                   Discharged to home  ...                          1
# 327586        Discharged/transferred to SNF  ...                          1
# 351214                   Discharged to home  ...                          3
# 914270                   Discharged to home  ...                          1
#
#               metformin  no_medication  insulin  Sulfonylureas Meglitinides  \
# encounter_id
# 499502                1              0        0              0            0
# 447319                0              1        0              0            0
# 309126                0              0        1              0            0
# 181183                1              0        1              1            0
# 359339                1              0        0              0            0
# ...                 ...            ...      ...            ...          ...
# 451150                0              1        0              0            0
# 549298                0              0        1              0            0
# 327586                0              0        1              0            0
# 351214                0              0        1              1            0
# 914270                0              0        0              0            0
#
#              Thiazolidinediones Alpha_Glucosidase_Inhibitors  \
# encounter_id
# 499502                        0                            0
# 447319                        0                            0
# 309126                        0                            0
# 181183                        0                            0
# 359339                        0                            0
# ...                         ...                          ...
# 451150                        0                            0
# 549298                        0                            0
# 327586                        0                            0
# 351214                        1                            0
# 914270                        1                            0
#
#               Combination_Medications Midpoint_Age
# encounter_id
# 499502                              0         85.0
# 447319                              0         25.0
# 309126                              0         35.0
# 181183                              0         55.0
# 359339                              0         65.0
# ...                               ...          ...
# 451150                              0         75.0
# 549298                              0         65.0
# 327586                              0         85.0
# 351214                              0      Unknown
# 914270                              0         65.0
#
# [30530 rows x 35 columns]

# %%
train[train['Midpoint_Age']=='Unknown'].shape[0]
# Out:
# 2217

# %%
test[test['Midpoint_Age']=='Unknown'].shape[0]
# Out:
# 1194

# %%
train['gender'].value_counts()
# Out:
# gender
# Female             38228
# Male               33005
# Unknown/Invalid        3
# Name: count, dtype: int64

# %%
train[train['gender'] == 'Unknown/Invalid']
# Out:
#               patient_id           gender payer_code  outpatient_visits  \
# encounter_id
# 208080          78119847  Unknown/Invalid         CP                  0
# 978787          60524946  Unknown/Invalid         CP                  0
# 876217         100695042  Unknown/Invalid       None                  0
#
#               emergency_visits  inpatient_visits admission_type  \
# encounter_id
# 208080                       0                 0      Emergency
# 978787                       0                 0      Emergency
# 876217                       0                 0       Elective
#
#              medical_specialty  average_pulse_bpm  \
# encounter_id
# 208080                 Unknown                111
# 978787                 Unknown                 87
# 876217              Cardiology                114
#
#                                           discharge_disposition  ...  \
# encounter_id                                                     ...
# 208080        Discharged/transferred to another rehab fac in...  ...
# 978787                                       Discharged to home  ...
# 876217                                       Discharged to home  ...
#
#              number_generic_medications  metformin  no_medication  insulin  \
# encounter_id
# 208080                                2          1              0        0
# 978787                                0          0              1        0
# 876217                                2          0              0        0
#
#               Sulfonylureas Meglitinides Thiazolidinediones  \
# encounter_id
# 208080                    0            0                  1
# 978787                    0            0                  0
# 876217                    1            0                  1
#
#              Alpha_Glucosidase_Inhibitors  Combination_Medications  \
# encounter_id
# 208080                                  0                        0
# 978787                                  0                        0
# 876217                                  0                        0
#
#              Midpoint_Age
# encounter_id
# 208080               75.0
# 978787               65.0
# 876217               75.0
#
# [3 rows x 37 columns]

# %%
#Female = 0 Male = 1 and the Unknown/Invalid becomes Female because it is the mode in the train
train['gender_binary'] = np.where(train['gender']== 'Male',1,0)
train.drop('gender', axis=1, inplace=True)

# %%
#Female = 0 Male = 1 and the Unknown/Invalid becomes Female because it is the mode in the train
test['gender_binary'] = np.where(test['gender']== 'Male',1,0)
test.drop('gender', axis=1, inplace=True)

# %%
train['gender_binary'].value_counts()
# Out:
# gender_binary
# 0    38231
# 1    33005
# Name: count, dtype: int64

# %%
bar_charts_categorical(train, "prescribed_diabetes_meds", "readmitted_binary")

# %%
#No = 0 Yes = 1
train['presc_diabetes_meds_binary'] = np.where(train['prescribed_diabetes_meds']== 'Yes',1,0)
train.drop('prescribed_diabetes_meds', axis=1, inplace=True)

# %%
#No = 0 Yes = 1
test['presc_diabetes_meds_binary'] = np.where(test['prescribed_diabetes_meds']== 'Yes',1,0)
test.drop('prescribed_diabetes_meds', axis=1, inplace=True)

# %%
#no change = 0 change = 1
train['change_in_meds_binary'] = np.where(train['change_in_meds']== 'Ch',1,0)
train.drop('change_in_meds', axis=1, inplace=True)

# %%
#no change = 0 change = 1
test['change_in_meds_binary'] = np.where(test['change_in_meds']== 'Ch',1,0)
test.drop('change_in_meds', axis=1, inplace=True)

# %%
bar_charts_categorical(train, "change_in_meds_binary", "readmitted_binary")

# %%
n_categorical_columns= len(train.select_dtypes(exclude=np.number).columns)
categorical_columns = list(train.select_dtypes(exclude=np.number).columns)

print('There are',n_categorical_columns, 'columns with categorical values:')
print()
print(categorical_columns)
# Out:
# There are 14 columns with categorical values:
#
# ['payer_code', 'admission_type', 'medical_specialty', 'discharge_disposition', 'admission_source', 'primary_diagnosis', 'secondary_diagnosis', 'additional_diagnosis', 'glucose_test_result', 'a1c_test_result', 'medication', 'readmitted_binary', 'readmitted_multiclass', 'Midpoint_Age']

# %%
n_categorical_columns= len(test.select_dtypes(exclude=np.number).columns)
categorical_columns = list(test.select_dtypes(exclude=np.number).columns)

print('There are',n_categorical_columns, 'columns with categorical values:')
print()
print(categorical_columns)
# Out:
# There are 12 columns with categorical values:
#
# ['payer_code', 'admission_type', 'medical_specialty', 'discharge_disposition', 'admission_source', 'primary_diagnosis', 'secondary_diagnosis', 'additional_diagnosis', 'glucose_test_result', 'a1c_test_result', 'medication', 'Midpoint_Age']

# %%
train['payer_code'].value_counts()
# Out:
# payer_code
# None    28201
# MC      22683
# HM       4319
# SP       3541
# BC       3292
# MD       2484
# CP       1762
# UN       1733
# CM       1347
# OG        729
# PO        405
# DM        378
# CH        102
# WC         99
# OT         61
# MP         54
# SI         45
# FR          1
# Name: count, dtype: int64

# %%
value_counts = train['payer_code'].value_counts(normalize=True)
replace_payer_code = value_counts[value_counts < 0.01].index

# Replacing the categories that have less than 1% of the number of rows

train['payer_code'] = train['payer_code'].replace(replace_payer_code, 'Other_code')

# %%
value_counts = test['payer_code'].value_counts(normalize=True)
replace_payer_code = value_counts[value_counts < 0.01].index

# Replacing the categories that have less than 1% of the number of rows

test['payer_code'] = test['payer_code'].replace(replace_payer_code, 'Other_code')

# %%
train['payer_code'].value_counts()
# Out:
# payer_code
# None          28201
# MC            22683
# HM             4319
# SP             3541
# BC             3292
# MD             2484
# CP             1762
# UN             1733
# CM             1347
# Other_code     1145
# OG              729
# Name: count, dtype: int64

# %%
test['payer_code'].value_counts()
# Out:
# payer_code
# None          12055
# MC             9756
# HM             1955
# SP             1466
# BC             1363
# MD             1048
# Other_code      811
# CP              771
# UN              715
# CM              590
# Name: count, dtype: int64

# %%
train['Has_Insurance'] = train['payer_code'].apply(lambda x: 0 if x == 'None' else 1)

# %%
test['Has_Insurance'] = test['payer_code'].apply(lambda x: 0 if x == 'None' else 1)

# %%
test['Has_Insurance'].value_counts()
# Out:
# Has_Insurance
# 1    18475
# 0    12055
# Name: count, dtype: int64

# %%
bar_charts_categorical(train, "Has_Insurance", "readmitted_binary")

# %%
bar_charts_categorical(train, "admission_type", "readmitted_binary")

# %%
train["admission_type"].value_counts()
# Out:
# admission_type
# Emergency        37742
# Elective         13211
# Urgent           13024
# Unknown           3706
# Not Available     3320
# Not Mapped         214
# Trauma Center       13
# Newborn              6
# Name: count, dtype: int64

# %%
train[train["admission_type"]=='Newborn'][['Midpoint_Age',"admission_type"]]
# Out:
#              Midpoint_Age admission_type
# encounter_id
# 268572               85.0        Newborn
# 531496               75.0        Newborn
# 129737               45.0        Newborn
# 394366               75.0        Newborn
# 203219                5.0        Newborn
# 792408               55.0        Newborn

# %%
train[train["admission_type"]=='Trauma Center'][['Midpoint_Age',"admission_type"]]
# Out:
#              Midpoint_Age admission_type
# encounter_id
# 693982               55.0  Trauma Center
# 150293            Unknown  Trauma Center
# 477599               55.0  Trauma Center
# 764141               85.0  Trauma Center
# 694176               55.0  Trauma Center
# 658996               75.0  Trauma Center
# 203632               45.0  Trauma Center
# 444992               55.0  Trauma Center
# 674039               55.0  Trauma Center
# 756804               85.0  Trauma Center
# 912221               65.0  Trauma Center
# 517727               95.0  Trauma Center
# 252632               55.0  Trauma Center

# %%
# We replace Unknown with Other_Type because the relation to the target is very similar, we can try to predict the unknown with
# Admission Source for example in the future (and some other columns)

train['admission_type'] = train['admission_type'].replace('Unknown', 'Other_type')
train['admission_type'] = train['admission_type'].replace('Trauma Center', 'Urgent')
train['admission_type'] = train['admission_type'].replace('Not Available', 'Other_type')
train['admission_type'] = train['admission_type'].replace('Not Mapped', 'Other_type')
train['admission_type'] = train['admission_type'].replace('Newborn', 'Other_type')
train['admission_type'] = train['admission_type'].replace({'Urgent': 'Urgent/Emergency', 'Emergency': 'Urgent/Emergency'})

train['admission_type'].value_counts(normalize=True)
# Out:
# admission_type
# Urgent/Emergency    0.712828
# Elective            0.185454
# Other_type          0.101718
# Name: proportion, dtype: float64

# %%
# We replace Unknown with Other_Type because the relation to the target is very similar, we can try to predict the unknown with
# Admission Source for example in the future (and some other columns)

test['admission_type'] = test['admission_type'].replace('Unknown', 'Other_type')
test['admission_type'] = test['admission_type'].replace('Trauma Center', 'Urgent')
test['admission_type'] = test['admission_type'].replace('Not Available', 'Other_type')
test['admission_type'] = test['admission_type'].replace('Not Mapped', 'Other_type')
test['admission_type'] = test['admission_type'].replace('Newborn', 'Other_type')
test['admission_type'] = test['admission_type'].replace({'Urgent': 'Urgent/Emergency', 'Emergency': 'Urgent/Emergency'})

test['admission_type'].value_counts(normalize=True)
# Out:
# admission_type
# Urgent/Emergency    0.711169
# Elective            0.185326
# Other_type          0.103505
# Name: proportion, dtype: float64

# %%
bar_charts_categorical(train, "admission_type", "readmitted_binary")

# %%
bar_charts_categorical(train, "medical_specialty", "readmitted_binary")

# %%
surgery = train[train['medical_specialty'].str.contains('Surgery|Surgeon|Reconstructive')]
train.loc[surgery.index, 'medical_specialty'] = 'Surgery'

pediatric = train[train['medical_specialty'].str.contains('Pediatrics|Pediatric')]
train.loc[pediatric.index, 'medical_specialty'] = 'Pediatric'

train['medical_specialty'].value_counts(normalize=True)
# Out:
# medical_specialty
# Unknown                                 0.490230
# InternalMedicine                        0.144478
# Emergency/Trauma                        0.074667
# Family/GeneralPractice                  0.073235
# Surgery                                 0.061556
# Cardiology                              0.052165
# Nephrology                              0.015947
# Orthopedics                             0.013392
# Radiologist                             0.011469
# Pulmonology                             0.008577
# Psychiatry                              0.008395
# Urology                                 0.006710
# ObstetricsandGynecology                 0.006570
# Pediatric                               0.005784
# Gastroenterology                        0.005573
# PhysicalMedicineandRehabilitation       0.003931
# Oncology                                0.003411
# Hematology/Oncology                     0.002148
# Neurology                               0.001937
# Otolaryngology                          0.001207
# Endocrinology                           0.001137
# Podiatry                                0.001039
# Psychology                              0.000955
# Hematology                              0.000744
# Gynecology                              0.000702
# Radiology                               0.000547
# Hospitalist                             0.000533
# Ophthalmology                           0.000379
# Osteopath                               0.000379
# SurgicalSpecialty                       0.000351
# InfectiousDiseases                      0.000323
# Obsterics&Gynecology-GynecologicOnco    0.000253
# Rheumatology                            0.000225
# Obstetrics                              0.000211
# Pathology                               0.000182
# OutreachServices                        0.000098
# AllergyandImmunology                    0.000084
# PhysicianNotFound                       0.000084
# Psychiatry-Child/Adolescent             0.000084
# Anesthesiology                          0.000070
# Endocrinology-Metabolism                0.000070
# Dentistry                               0.000056
# DCPTEAM                                 0.000028
# Resident                                0.000028
# Speech                                  0.000014
# SportsMedicine                          0.000014
# Proctology                              0.000014
# Neurophysiology                         0.000014
# Name: proportion, dtype: float64

# %%
surgery = test[test['medical_specialty'].str.contains('Surgery|Surgeon|Reconstructive')]
test.loc[surgery.index, 'medical_specialty'] = 'Surgery'

pediatric = test[test['medical_specialty'].str.contains('Pediatrics|Pediatric')]
test.loc[pediatric.index, 'medical_specialty'] = 'Pediatric'

test['medical_specialty'].value_counts(normalize=True)
# Out:
# medical_specialty
# Unknown                                 0.492204
# InternalMedicine                        0.142254
# Emergency/Trauma                        0.073567
# Family/GeneralPractice                  0.072814
# Surgery                                 0.063020
# Cardiology                              0.053587
# Nephrology                              0.015624
# Orthopedics                             0.014609
# Radiologist                             0.010580
# Pulmonology                             0.008516
# Psychiatry                              0.008385
# Urology                                 0.006780
# ObstetricsandGynecology                 0.006649
# Gastroenterology                        0.005470
# Pediatric                               0.005241
# PhysicalMedicineandRehabilitation       0.003636
# Oncology                                0.003439
# Neurology                               0.002129
# Hematology/Oncology                     0.001769
# Endocrinology                           0.001277
# Otolaryngology                          0.001277
# Psychology                              0.001081
# Hematology                              0.000950
# Podiatry                                0.000852
# Hospitalist                             0.000622
# InfectiousDiseases                      0.000459
# Radiology                               0.000459
# Osteopath                               0.000393
# Ophthalmology                           0.000360
# SurgicalSpecialty                       0.000262
# Gynecology                              0.000262
# Anesthesiology                          0.000229
# Obsterics&Gynecology-GynecologicOnco    0.000229
# OutreachServices                        0.000164
# PhysicianNotFound                       0.000164
# Pathology                               0.000131
# Obstetrics                              0.000131
# DCPTEAM                                 0.000131
# Endocrinology-Metabolism                0.000098
# AllergyandImmunology                    0.000033
# Psychiatry-Addictive                    0.000033
# Dermatology                             0.000033
# Rheumatology                            0.000033
# Perinatology                            0.000033
# Psychiatry-Child/Adolescent             0.000033
# Name: proportion, dtype: float64

# %%
value_counts = train['medical_specialty'].value_counts(normalize=True)
replace_medical_specialty = value_counts[value_counts < 0.05].index

# We dont think making predictions or assumptions on the Unknowns here makes sense (we can recap this)
train['medical_specialty'] = train['medical_specialty'].replace('Unknown', 'Other_specialty')
train['medical_specialty'] = train['medical_specialty'].replace(replace_medical_specialty, 'Other_specialty')
train['medical_specialty'].value_counts(normalize=True)
# Out:
# medical_specialty
# Other_specialty           0.593899
# InternalMedicine          0.144478
# Emergency/Trauma          0.074667
# Family/GeneralPractice    0.073235
# Surgery                   0.061556
# Cardiology                0.052165
# Name: proportion, dtype: float64

# %%
value_counts = test['medical_specialty'].value_counts(normalize=True)
replace_medical_specialty = value_counts[value_counts < 0.05].index

# We don't think making predictions or assumptions on the Unknowns here makes sense (we can recap this)
test['medical_specialty'] = test['medical_specialty'].replace('Unknown', 'Other_specialty')
test['medical_specialty'] = test['medical_specialty'].replace(replace_medical_specialty, 'Other_specialty')
test['medical_specialty'].value_counts(normalize=True)
# Out:
# medical_specialty
# Other_specialty           0.594759
# InternalMedicine          0.142254
# Emergency/Trauma          0.073567
# Family/GeneralPractice    0.072814
# Surgery                   0.063020
# Cardiology                0.053587
# Name: proportion, dtype: float64

# %%
train['medical_specialty'] = train['medical_specialty'].str.strip().str.replace('/', '_')

# %%
test['medical_specialty'] = test['medical_specialty'].str.strip().str.replace('/', '_')

# %%
bar_charts_categorical(train, "medical_specialty", "readmitted_binary")

# %%
train['discharge_disposition'].value_counts(normalize=True)
# Out:
# discharge_disposition
# Discharged to home                                                                                           0.593183
# Discharged/transferred to SNF                                                                                0.137290
# Discharged/transferred to home with home health service                                                      0.126411
# Unknown                                                                                                      0.036358
# Discharged/transferred to another short term hospital                                                        0.020888
# Discharged/transferred to another rehab fac including rehab units of a hospital .                            0.019555
# Expired                                                                                                      0.015933
# Discharged/transferred to another type of inpatient care institution                                         0.011539
# Not Mapped                                                                                                   0.009532
# Discharged/transferred to ICF                                                                                0.008016
# Left AMA                                                                                                     0.005910
# Discharged/transferred to a long term care hospital.                                                         0.003931
# Hospice / medical facility                                                                                   0.003664
# Hospice / home                                                                                               0.003622
# Discharged/transferred/referred to a psychiatric hospital of psychiatric distinct part unit of a hospital    0.001376
# Discharged/transferred to home under care of Home IV provider                                                0.001137
# Discharged/transferred within this institution to Medicare approved swing bed                                0.000618
# Discharged/transferred to a nursing facility certified under Medicaid but not certified under Medicare.      0.000449
# Admitted as an inpatient to this hospital                                                                    0.000182
# Discharged/transferred/referred to this institution for outpatient services                                  0.000112
# Discharged/transferred/referred another institution for outpatient services                                  0.000098
# Expired at home. Medicaid only, hospice.                                                                     0.000084
# Discharged/transferred to a federal health care facility.                                                    0.000042
# Neonate discharged to another hospital for neonatal aftercare                                                0.000028
# Still patient or expected to return for outpatient services                                                  0.000028
# Expired in a medical facility. Medicaid only, hospice.                                                       0.000014
# Name: proportion, dtype: float64

# %%
bar_charts_categorical(train, "discharge_disposition", "readmitted_binary")

# %%
expired = train[train['discharge_disposition'].str.contains('Expired')]
train.loc[expired.index, 'discharge_disposition'] = 'Expired'

hospice = train[train['discharge_disposition'].str.contains('Hospice')]
train.loc[hospice.index, 'discharge_disposition'] = 'Hospice'

another_medical_facility = ['Discharged/transferred to SNF', 'Discharged/transferred to another short term hospital', 'Discharged/transferred to another rehab fac including rehab units of a hospital', 'Discharged/transferred to another type of inpatient care institution', 'Discharged/transferred to a long term care hospital', 'Discharged/transferred to a federal health care facility','Neonate discharged to another hospital for neonatal aftercare']
train['discharge_disposition'] = train['discharge_disposition'].replace(another_medical_facility, 'Transferred_to_another_medical_facility')

outpatient = ['Discharged/transferred/referred to this institution for outpatient services','Discharged/transferred/referred another institution for outpatient services']
train['discharge_disposition'] = train['discharge_disposition'].replace(outpatient, 'Discharged_transferred_referred_another_this_institution_for_outpatient_services')

home = train[train['discharge_disposition'].str.contains('home')]
train.loc[home.index, 'discharge_disposition'] = 'Discharged_to_home'

other = ['Discharged/transferred to another rehab fac including rehab units of a hospital','Discharged/transferred to ICF','Hospice',
         'Left AMA','Discharged/transferred to a long term care hospital.','Discharged/transferred/referred to a psychiatric hospital of psychiatric distinct part unit of a hospital',
         'Discharged/transferred within this institution to Medicare approved swing bed','Discharged/transferred to a nursing facility certified under Medicaid but not certified under Medicare.',
         'Discharged/transferred/referred another/this institution for outpatient services',
         'Discharged/transferred to a federal health care facility.','Discharged/transferred to another rehab fac including rehab units of a hospital .','Unknown',
         'Admitted as an inpatient to this hospital', 'Still patient or expected to return for outpatient services',
        'Discharged_transferred_referred_another_this_institution_for_outpatient_services']

train['discharge_disposition'] = train['discharge_disposition'].replace(other, 'Other')

train['discharge_disposition'] = train['discharge_disposition'].replace('Not Mapped', 'Unknown')

train['discharge_disposition'] = train['discharge_disposition'].replace('Unknown', 'Discharged_to_home')

train['discharge_disposition'].value_counts(normalize=True)
# Out:
# discharge_disposition
# Discharged_to_home                         0.730263
# Transferred_to_another_medical_facility    0.169746
# Other                                      0.083960
# Expired                                    0.016031
# Name: proportion, dtype: float64

# %%
expired = test[test['discharge_disposition'].str.contains('Expired')]
test.loc[expired.index, 'discharge_disposition'] = 'Expired'

hospice = test[test['discharge_disposition'].str.contains('Hospice')]
test.loc[hospice.index, 'discharge_disposition'] = 'Hospice'

another_medical_facility = ['Discharged/transferred to SNF', 'Discharged/transferred to another short term hospital', 'Discharged/transferred to another rehab fac including rehab units of a hospital', 'Discharged/transferred to another type of inpatient care institution', 'Discharged/transferred to a long term care hospital', 'Discharged/transferred to a federal health care facility','Neonate discharged to another hospital for neonatal aftercare']
test['discharge_disposition'] = test['discharge_disposition'].replace(another_medical_facility, 'Transferred_to_another_medical_facility')

outpatient = ['Discharged/transferred/referred to this institution for outpatient services','Discharged/transferred/referred another institution for outpatient services']
test['discharge_disposition'] = test['discharge_disposition'].replace(outpatient, 'Discharged_transferred_referred_another_this_institution_for_outpatient_services')

home = test[test['discharge_disposition'].str.contains('home')]
test.loc[home.index, 'discharge_disposition'] = 'Discharged_to_home'

other = ['Discharged/transferred to another rehab fac including rehab units of a hospital','Discharged/transferred to ICF','Hospice',
         'Left AMA','Discharged/transferred to a long term care hospital.','Discharged/transferred/referred to a psychiatric hospital of psychiatric distinct part unit of a hospital',
         'Discharged/transferred within this institution to Medicare approved swing bed','Discharged/transferred to a nursing facility certified under Medicaid but not certified under Medicare.',
         'Discharged/transferred/referred another/this institution for outpatient services',
         'Discharged/transferred to a federal health care facility.','Discharged/transferred to another rehab fac including rehab units of a hospital .','Unknown',
         'Admitted as an inpatient to this hospital', 'Still patient or expected to return for outpatient services',
         'Discharged_transferred_referred_another_this_institution_for_outpatient_services']

test['discharge_disposition'] = test['discharge_disposition'].replace(other, 'Other')

test['discharge_disposition'] = test['discharge_disposition'].replace('Not Mapped', 'Unknown')

test['discharge_disposition'] = test['discharge_disposition'].replace('Unknown', 'Discharged_to_home')

test['discharge_disposition'].value_counts(normalize=True)
# Out:
# discharge_disposition
# Discharged_to_home                         0.727547
# Transferred_to_another_medical_facility    0.169669
# Other                                      0.086079
# Expired                                    0.016705
# Name: proportion, dtype: float64

# %%
bar_charts_categorical(train, "discharge_disposition", "readmitted_binary")

# %%
unknown = [' Not Mapped',' Not Available']
train['admission_source'] = train['admission_source'].replace(unknown, 'Unknown')
train['admission_source'].value_counts(normalize=True)
# Out:
# admission_source
#  Emergency Room                                               0.565992
#  Physician Referral                                           0.290275
# Unknown                                                       0.068968
# Transfer from a hospital                                      0.031304
#  Transfer from another health care facility                   0.021927
# Clinic Referral                                               0.010935
#  Transfer from a Skilled Nursing Facility (SNF)               0.008353
# HMO Referral                                                  0.001811
#  Court/Law Enforcement                                        0.000154
#  Transfer from hospital inpt/same fac reslt in a sep claim    0.000112
#  Transfer from critial access hospital                        0.000098
#  Transfer from Ambulatory Surgery Center                      0.000028
#  Extramural Birth                                             0.000014
# Normal Delivery                                               0.000014
#  Sick Baby                                                    0.000014
# Name: proportion, dtype: float64

# %%
unknown = [' Not Mapped',' Not Available']
test['admission_source'] = test['admission_source'].replace(unknown, 'Unknown')
test['admission_source'].value_counts(normalize=True)
# Out:
# admission_source
#  Emergency Room                                               0.562561
#  Physician Referral                                           0.291091
# Unknown                                                       0.070554
# Transfer from a hospital                                      0.031346
#  Transfer from another health care facility                   0.022994
# Clinic Referral                                               0.010645
#  Transfer from a Skilled Nursing Facility (SNF)               0.008516
# HMO Referral                                                  0.001900
#  Court/Law Enforcement                                        0.000164
#  Transfer from hospital inpt/same fac reslt in a sep claim    0.000131
# Normal Delivery                                               0.000033
#  Transfer from critial access hospital                        0.000033
#  Extramural Birth                                             0.000033
# Name: proportion, dtype: float64

# %%
train['admission_source'].unique()
# Out:
# array([' Emergency Room', 'Clinic Referral', 'Unknown',
#        ' Transfer from another health care facility',
#        ' Physician Referral', 'Transfer from a hospital', 'HMO Referral',
#        ' Transfer from a Skilled Nursing Facility (SNF)',
#        ' Court/Law Enforcement',
#        ' Transfer from hospital inpt/same fac reslt in a sep claim',
#        ' Transfer from critial access hospital', ' Extramural Birth',
#        'Normal Delivery', ' Transfer from Ambulatory Surgery Center',
#        ' Sick Baby'], dtype=object)

# %%
train['admission_source'] = train['admission_source'].str.strip().str.replace(' ', '_')

# %%
test['admission_source'] = test['admission_source'].str.strip().str.replace(' ', '_')

# %%
train['admission_source'].unique()
# Out:
# array(['Emergency_Room', 'Clinic_Referral', 'Unknown',
#        'Transfer_from_another_health_care_facility', 'Physician_Referral',
#        'Transfer_from_a_hospital', 'HMO_Referral',
#        'Transfer_from_a_Skilled_Nursing_Facility_(SNF)',
#        'Court/Law_Enforcement',
#        'Transfer_from_hospital_inpt/same_fac_reslt_in_a_sep_claim',
#        'Transfer_from_critial_access_hospital', 'Extramural_Birth',
#        'Normal_Delivery', 'Transfer_from_Ambulatory_Surgery_Center',
#        'Sick_Baby'], dtype=object)

# %%
test['admission_source'].unique()
# Out:
# array(['Emergency_Room', 'Physician_Referral', 'Unknown',
#        'Transfer_from_another_health_care_facility',
#        'Transfer_from_a_hospital',
#        'Transfer_from_a_Skilled_Nursing_Facility_(SNF)',
#        'Clinic_Referral', 'Court/Law_Enforcement', 'HMO_Referral',
#        'Transfer_from_hospital_inpt/same_fac_reslt_in_a_sep_claim',
#        'Normal_Delivery', 'Transfer_from_critial_access_hospital',
#        'Extramural_Birth'], dtype=object)

# %%
bar_charts_categorical(train, "admission_source", "readmitted_binary")

# %%
train['admission_source'] = train['admission_source'].replace('Physician_Referral', 'Referral')
train['admission_source'] = train['admission_source'].replace('Clinic_Referral', 'Referral')
train['admission_source'] = train['admission_source'].replace('HMO_Referral', 'Referral')

# %%
test['admission_source'] = test['admission_source'].replace('Physician_Referral', 'Referral')
test['admission_source'] = test['admission_source'].replace('Clinic_Referral', 'Referral')
test['admission_source'] = test['admission_source'].replace('HMO_Referral', 'Referral')

# %%
value_counts = train['admission_source'].value_counts(normalize=True)
replace_admission_source = value_counts[value_counts < 0.05].index

train['admission_source'] = train['admission_source'].replace(replace_admission_source, 'Other_source')
# Unknown provavelmente é os casos onde nao vem de lado nenhum
train['admission_source'] = train['admission_source'].replace('Unknown', 'No_source')
train['admission_source'].value_counts(normalize=True)
# Out:
# admission_source
# Emergency_Room    0.565992
# Referral          0.303021
# No_source         0.068968
# Other_source      0.062019
# Name: proportion, dtype: float64

# %%
value_counts = test['admission_source'].value_counts(normalize=True)
replace_admission_source = value_counts[value_counts < 0.05].index

test['admission_source'] = test['admission_source'].replace(replace_admission_source, 'Other_source')
# 'Unknown' probably represents cases where there is no source
test['admission_source'] = test['admission_source'].replace('Unknown', 'No_source')
test['admission_source'].value_counts(normalize=True)
# Out:
# admission_source
# Emergency_Room    0.562561
# Referral          0.303636
# No_source         0.070554
# Other_source      0.063249
# Name: proportion, dtype: float64

# %%
bar_charts_categorical(train, "admission_source", "readmitted_binary")

# %%
train[['admission_type', 'admission_source']]
# Out:
#                 admission_type admission_source
# encounter_id
# 533253        Urgent/Emergency   Emergency_Room
# 426224        Urgent/Emergency         Referral
# 634063              Other_type        No_source
# 890610        Urgent/Emergency     Other_source
# 654194                Elective         Referral
# ...                        ...              ...
# 660160                Elective         Referral
# 826429        Urgent/Emergency         Referral
# 332030              Other_type        No_source
# 757560        Urgent/Emergency   Emergency_Room
# 459757        Urgent/Emergency   Emergency_Room
#
# [71236 rows x 2 columns]

# %%
def diagosis_types_division(x):
    try:
        x_float = float(x)
        x_int = int(x_float)
        if x_int <= 459 and x_int >= 390 or x_int == 785:
            return 'Circulatory'
        elif x_int <= 519 and x_int >= 460 or x_int == 786:
            return 'Respiratory'
        elif x_int <= 579 and x_int >= 520 or x_int == 787:
            return 'Digestive'
        elif x_float < 251 and x_float >= 250:
            return 'Diabetes'
        elif x_int <= 999 and x_int >= 800:
            return 'Injury'
        elif x_int <= 739 and x_int >= 710:
            return 'Musculoskeletal'
        elif x_int <= 629 and x_int >= 580 or x_int == 788:
            return 'Genitourinary'
        elif x_int <= 239 and x_int >= 140:
            return 'Neoplasms'
        # Codes for 'Other' categories
        elif (x_int <= 799 and x_int >= 790) or x_int in {780, 781, 784}:
            return 'Other'
        elif (x_int <= 249 and x_int >= 240) or (x_int <= 279 and x_int >= 251):
            return 'Other'
        elif x_int <= 709 and x_int >= 680:
            return 'Other'
        elif x_int <= 999 and x_int >= 290:
            return 'Other'
        # If the code doesn't match any category, return 'Other'
        else:
            return 'Other'
    except:
        return 'Other'
    
train['primary_diagnosis_types'] = train['primary_diagnosis'].apply(diagosis_types_division)
train['secondary_diagnosis_types'] = train['secondary_diagnosis'].apply(diagosis_types_division)
train['additional_diagnosis_types'] = train['additional_diagnosis'].apply(diagosis_types_division)

# %%
test['primary_diagnosis_types'] = test['primary_diagnosis'].apply(diagosis_types_division)
test['secondary_diagnosis_types'] = test['secondary_diagnosis'].apply(diagosis_types_division)
test['additional_diagnosis_types'] = test['additional_diagnosis'].apply(diagosis_types_division)

# %%
train = train.drop(['primary_diagnosis','secondary_diagnosis','additional_diagnosis'], axis=1)

# %%
test = test.drop(['primary_diagnosis','secondary_diagnosis','additional_diagnosis'], axis=1)

# %%
train['primary_diagnosis_types'].value_counts(normalize=True)
# Out:
# primary_diagnosis_types
# Circulatory        0.298838
# Other              0.178323
# Respiratory        0.142302
# Digestive          0.093590
# Diabetes           0.085687
# Injury             0.068519
# Genitourinary      0.050382
# Musculoskeletal    0.048332
# Neoplasms          0.034028
# Name: proportion, dtype: float64

# %%
test['primary_diagnosis_types'].value_counts(normalize=True)
# Out:
# primary_diagnosis_types
# Circulatory        0.299672
# Other              0.179823
# Respiratory        0.140387
# Digestive          0.091975
# Diabetes           0.086898
# Injury             0.068556
# Genitourinary      0.050049
# Musculoskeletal    0.049591
# Neoplasms          0.033049
# Name: proportion, dtype: float64

# %%
bar_charts_categorical(train, "primary_diagnosis_types", "readmitted_binary")

# %%
train['secondary_diagnosis_types'].value_counts(normalize=True)
# Out:
# secondary_diagnosis_types
# Circulatory        0.313676
# Other              0.264291
# Diabetes           0.125470
# Respiratory        0.107347
# Genitourinary      0.082346
# Digestive          0.040668
# Neoplasms          0.024777
# Injury             0.024187
# Musculoskeletal    0.017238
# Name: proportion, dtype: float64

# %%
test['secondary_diagnosis_types'].value_counts(normalize=True)
# Out:
# secondary_diagnosis_types
# Circulatory        0.312349
# Other              0.264789
# Diabetes           0.126302
# Respiratory        0.106387
# Genitourinary      0.082214
# Digestive          0.041697
# Neoplasms          0.025614
# Injury             0.023092
# Musculoskeletal    0.017557
# Name: proportion, dtype: float64

# %%
bar_charts_categorical(train, "secondary_diagnosis_types", "readmitted_binary")

# %%
train['additional_diagnosis_types'].value_counts(normalize=True)
# Out:
# additional_diagnosis_types
# Other              0.301294
# Circulatory        0.298080
# Diabetes           0.167429
# Respiratory        0.072014
# Genitourinary      0.066104
# Digestive          0.038829
# Injury             0.019414
# Musculoskeletal    0.018628
# Neoplasms          0.018207
# Name: proportion, dtype: float64

# %%
test['additional_diagnosis_types'].value_counts(normalize=True)
# Out:
# additional_diagnosis_types
# Other              0.299869
# Circulatory        0.297150
# Diabetes           0.171307
# Respiratory        0.072977
# Genitourinary      0.064559
# Digestive          0.038126
# Musculoskeletal    0.019260
# Injury             0.018441
# Neoplasms          0.018310
# Name: proportion, dtype: float64

# %%
bar_charts_categorical(train, "additional_diagnosis_types", "readmitted_binary")

# %%
train['glucose_test_result'].value_counts(normalize=True)
# Out:
# glucose_test_result
# Not_taken    0.948228
# Norm         0.025352
# >200         0.014810
# >300         0.011609
# Name: proportion, dtype: float64

# %%
train['glucose_test_result'] = train['glucose_test_result'].replace('>200', 'High')
train['glucose_test_result'] = train['glucose_test_result'].replace('>300', 'High')

# %%
test['glucose_test_result'] = test['glucose_test_result'].replace('>200', 'High')
test['glucose_test_result'] = test['glucose_test_result'].replace('>300', 'High')

# %%
train['glucose_test_result'].value_counts(normalize=True)
# Out:
# glucose_test_result
# Not_taken    0.948228
# High         0.026419
# Norm         0.025352
# Name: proportion, dtype: float64

# %%
test['glucose_test_result'].value_counts(normalize=True)
# Out:
# glucose_test_result
# Not_taken    0.945693
# High         0.028398
# Norm         0.025909
# Name: proportion, dtype: float64

# %%
bar_charts_categorical(train, "glucose_test_result", "readmitted_binary")

# %%
train['a1c_test_result'].value_counts(normalize=True)
# Out:
# a1c_test_result
# Not_taken    0.832725
# >8           0.080086
# Norm         0.049175
# >7           0.038014
# Name: proportion, dtype: float64

# %%
train['a1c_test_result'] = train['a1c_test_result'].replace('>7', 'High')
train['a1c_test_result'] = train['a1c_test_result'].replace('>8', 'High')

# %%
test['a1c_test_result'] = test['a1c_test_result'].replace('>7', 'High')
test['a1c_test_result'] = test['a1c_test_result'].replace('>8', 'High')

# %%
train['a1c_test_result'].value_counts(normalize=True)
# Out:
# a1c_test_result
# Not_taken    0.832725
# High         0.118100
# Norm         0.049175
# Name: proportion, dtype: float64

# %%
test['a1c_test_result'].value_counts(normalize=True)
# Out:
# a1c_test_result
# Not_taken    0.832886
# High         0.118408
# Norm         0.048706
# Name: proportion, dtype: float64

# %%
bar_charts_categorical(train, "a1c_test_result", "readmitted_binary")

# %%
train['Midpoint_Age'] = train['Midpoint_Age'].replace('Unknown', np.nan)

# %%
test['Midpoint_Age'] = test['Midpoint_Age'].replace('Unknown', np.nan)

# %%
train['Midpoint_Age'].isna().sum()
# Out:
# 2217

# %%
test['Midpoint_Age'].isna().sum()
# Out:
# 1194

# %%
def label_pulse(row):
    if row['Midpoint_Age']==5.0:
        if row['average_pulse_bpm'] >= 70 and row['average_pulse_bpm'] <= 130:
            return 1
        else:
            return 0
    elif row['Midpoint_Age']<= 45.0 and row['Midpoint_Age'] >= 25.0:
        if row['average_pulse_bpm'] >= 60 and row['average_pulse_bpm'] <= 110:
            return 1
        else:
            return 0
    elif row['Midpoint_Age']==55.0:
        if row['average_pulse_bpm'] >= 60 and row['average_pulse_bpm'] <= 100:
            return 1
        else:
            return 0
    elif row['Midpoint_Age']>=65.0:
        if row['average_pulse_bpm'] >= 60 and row['average_pulse_bpm'] <= 95:
            return 1
        else:
            return 0
    else:
        if row['average_pulse_bpm'] >= 60 and row['average_pulse_bpm'] <= 100:
            return 1
        else:
            return 0

train['is_normal_pulse'] = train.apply(lambda row: label_pulse(row), axis=1)

# %%
test['is_normal_pulse'] = test.apply(lambda row: label_pulse(row), axis=1)

# %%
train['is_normal_pulse'].value_counts(normalize=True)
# Out:
# is_normal_pulse
# 0    0.512283
# 1    0.487717
# Name: proportion, dtype: float64

# %%
test['is_normal_pulse'].value_counts(normalize=True)
# Out:
# is_normal_pulse
# 0    0.511595
# 1    0.488405
# Name: proportion, dtype: float64

# %%
bar_charts_categorical(train, "is_normal_pulse", "readmitted_binary")

# %%
bar_charts_categorical(train, "average_pulse_bpm", "readmitted_binary")

# %%
bar_charts_categorical(train, 'length_of_stay', "readmitted_binary")

# %%
bar_charts_categorical(train, 'number_lab_tests', "readmitted_binary")

# %%
bar_charts_categorical(train, 'non_lab_procedures', "readmitted_binary")

# %%
train['non_lab_procedures'].value_counts(normalize=True)
# Out:
# non_lab_procedures
# 0    0.458083
# 1    0.204012
# 2    0.124881
# 3    0.092846
# 6    0.048824
# 4    0.041103
# 5    0.030252
# Name: proportion, dtype: float64

# %%
test['non_lab_procedures'].value_counts(normalize=True)
# Out:
# non_lab_procedures
# 0    0.459220
# 1    0.203374
# 2    0.125156
# 3    0.092663
# 6    0.048346
# 4    0.041009
# 5    0.030233
# Name: proportion, dtype: float64

# %%
bar_charts_categorical(train, 'number_of_medications', "readmitted_binary")

# %%
bar_charts_categorical(train, 'number_diagnoses', "readmitted_binary")

# %%
bar_charts_categorical(train, 'outpatient_visits', "readmitted_binary")

# %%
bar_charts_categorical(train, 'emergency_visits', "readmitted_binary")

# %%
bar_charts_categorical(train, 'inpatient_visits', "readmitted_binary")

# %%
train.drop(['patient_id'], axis = 1, inplace = True)

# %%
test.drop(['patient_id'], axis = 1, inplace = True)

# %%
train.drop(['medication'], axis = 1, inplace = True)

# %%
test.drop(['medication'], axis = 1, inplace = True)

# %%
train['Total_visits'] = train['inpatient_visits'] + train['outpatient_visits'] + train['emergency_visits']

# %%
test['Total_visits'] = test['inpatient_visits'] + test['outpatient_visits'] + test['emergency_visits']

# %%
train['Serious_condition_visits'] = train['inpatient_visits'] + train['emergency_visits']

# %%
test['Serious_condition_visits'] = test['inpatient_visits'] + test['emergency_visits']

# %%
# Drop because its exactly the same as presc_diabetes_meds_binary
train.drop(['no_medication'], axis=1, inplace=True)

# %%
# Drop because its exactly the same as presc_diabetes_meds_binary
test.drop(['no_medication'], axis=1, inplace=True)

# %% [markdown]
# # Train Test Split

# %%
X = train.drop(['readmitted_binary', 'readmitted_multiclass'], axis=1)
y_binary = train['readmitted_binary']
y_multiclass = train['readmitted_multiclass']

# %%
X_train_bin, X_val_bin, y_train_bin, y_val_bin = train_test_split(X, y_multiclass,
                                                  test_size = 0.25, 
                                                  random_state = 0, 
                                                  stratify = y_binary, 
                                                  shuffle = True)

# %% [markdown]
# # Outliers

# %%
metric_features = ['average_pulse_bpm', 'length_of_stay', 'number_lab_tests', 'non_lab_procedures',
            'number_of_medications', 'number_diagnoses', 'number_generic_medications', 'outpatient_visits',
            'emergency_visits', 'inpatient_visits', 'Midpoint_Age', 'Total_visits', 'Serious_condition_visits']

# %%
# Determine the number of rows needed for the plot
n_rows = int(np.ceil(len(metric_features) / 5))

# Create a figure and axes objects
fig, axs = plt.subplots(n_rows, 5, figsize=(15, n_rows * 5))

# Flatten the axes array and remove extra subplots
axs = axs.flatten()
for ax in axs[len(metric_features):]:
    fig.delaxes(ax)

# Create a boxplot for each column
for i, feature in enumerate(metric_features):
    sns.boxplot(x=X_train_bin[feature], ax=axs[i])
    axs[i].set_title(f'Boxplot of {feature}')

# Display the plot
plt.tight_layout()
plt.show()

# %%
def TestIndependence(X,y,var,alpha=0.05):        
    dfObserved = pd.crosstab(y,X) 
    chi2, p, dof, expected = stats.chi2_contingency(dfObserved.values)
    dfExpected = pd.DataFrame(expected, columns=dfObserved.columns, index = dfObserved.index)
    if p<alpha:
        result="{0} is IMPORTANT for Prediction".format(var)
    else:
        result="{0} is NOT an important predictor. (Discard {0} from model)".format(var)
        
    print(result)

# %%
for categorical_columns in X_train_bin:
    TestIndependence(X_train_bin[categorical_columns],y_train_bin, categorical_columns)
# Out:
# payer_code is IMPORTANT for Prediction
# outpatient_visits is IMPORTANT for Prediction
# emergency_visits is IMPORTANT for Prediction
# inpatient_visits is IMPORTANT for Prediction
# admission_type is IMPORTANT for Prediction
# medical_specialty is IMPORTANT for Prediction
# average_pulse_bpm is NOT an important predictor. (Discard average_pulse_bpm from model)
# discharge_disposition is IMPORTANT for Prediction
# admission_source is IMPORTANT for Prediction
# length_of_stay is IMPORTANT for Prediction
# number_lab_tests is IMPORTANT for Prediction
# non_lab_procedures is IMPORTANT for Prediction
# number_of_medications is IMPORTANT for Prediction
# number_diagnoses is IMPORTANT for Prediction
# glucose_test_result is IMPORTANT for Prediction
# a1c_test_result is IMPORTANT for Prediction
# race_caucasian is IMPORTANT for Prediction
# number_generic_medications is IMPORTANT for Prediction
# metformin is IMPORTANT for Prediction
# insulin is IMPORTANT for Prediction
# Sulfonylureas is IMPORTANT for Prediction
# Meglitinides is IMPORTANT for Prediction
# Thiazolidinediones is IMPORTANT for Prediction
# Alpha_Glucosidase_Inhibitors is IMPORTANT for Prediction
# Combination_Medications is NOT an important predictor. (Discard Combination_Medications from model)
# Midpoint_Age is IMPORTANT for Prediction
# gender_binary is IMPORTANT for Prediction
# presc_diabetes_meds_binary is IMPORTANT for Prediction
# change_in_meds_binary is IMPORTANT for Prediction
# Has_Insurance is NOT an important predictor. (Discard Has_Insurance from model)
# primary_diagnosis_types is IMPORTANT for Prediction
# secondary_diagnosis_types is IMPORTANT for Prediction
# additional_diagnosis_types is IMPORTANT for Prediction
# is_normal_pulse is NOT an important predictor. (Discard is_normal_pulse from model)
# Total_visits is IMPORTANT for Prediction
# Serious_condition_visits is IMPORTANT for Prediction

# %%
X_train_bin.shape
# Out:
# (53427, 36)

# %%
X_train_bin.drop(['average_pulse_bpm','Combination_Medications','Has_Insurance','is_normal_pulse'], axis = 1, inplace = True) 
X_val_bin.drop(['average_pulse_bpm','Combination_Medications','Has_Insurance','is_normal_pulse'], axis = 1, inplace = True)

# %%
X_train_bin.shape
# Out:
# (53427, 32)

# %%
X_val_bin.shape
# Out:
# (17809, 32)

# %%
test.shape
# Out:
# (30530, 36)

# %%
test.drop(['average_pulse_bpm','Combination_Medications','Has_Insurance','is_normal_pulse'], axis = 1, inplace = True)

# %%
test.shape
# Out:
# (30530, 32)

# %% [markdown]
# ## Encoding categorical variables

# %%
X_train_bin.dtypes
# Out:
# payer_code                       object
# outpatient_visits                 int64
# emergency_visits                  int64
# inpatient_visits                  int64
# admission_type                   object
# medical_specialty                object
# discharge_disposition            object
# admission_source                 object
# length_of_stay                    int64
# number_lab_tests                  int64
# non_lab_procedures                int64
# number_of_medications             int64
# number_diagnoses                  int64
# glucose_test_result              object
# a1c_test_result                  object
# race_caucasian                    int64
# number_generic_medications        int64
# metformin                         int64
# insulin                           int64
# Sulfonylureas                     int64
# Meglitinides                      int64
# Thiazolidinediones                int64
# Alpha_Glucosidase_Inhibitors      int64
# Midpoint_Age                    float64
# gender_binary                     int64
# presc_diabetes_meds_binary        int64
# change_in_meds_binary             int64
# primary_diagnosis_types          object
# secondary_diagnosis_types        object
# additional_diagnosis_types       object
# Total_visits                      int64
# Serious_condition_visits          int64
# dtype: object

# %%
test.columns
# Out:
# Index(['payer_code', 'outpatient_visits', 'emergency_visits',
#        'inpatient_visits', 'admission_type', 'medical_specialty',
#        'discharge_disposition', 'admission_source', 'length_of_stay',
#        'number_lab_tests', 'non_lab_procedures', 'number_of_medications',
#        'number_diagnoses', 'glucose_test_result', 'a1c_test_result',
#        'race_caucasian', 'number_generic_medications', 'metformin', 'insulin',
#        'Sulfonylureas', 'Meglitinides', 'Thiazolidinediones',
#        'Alpha_Glucosidase_Inhibitors', 'Midpoint_Age', 'gender_binary',
#        'presc_diabetes_meds_binary', 'change_in_meds_binary',
#        'primary_diagnosis_types', 'secondary_diagnosis_types',
#        'additional_diagnosis_types', 'Total_visits',
#        'Serious_condition_visits'],
#       dtype='object')

# %%
columns_to_encode = ['payer_code', 'admission_type', 'medical_specialty','discharge_disposition', 'admission_source',
                     'primary_diagnosis_types', 'secondary_diagnosis_types', 'additional_diagnosis_types', 'glucose_test_result', 
                     'a1c_test_result']

other_columns_train = pd.DataFrame(X_train_bin.drop(columns_to_encode, axis=1))
other_columns_val = pd.DataFrame(X_val_bin.drop(columns_to_encode, axis=1))
other_columns_test = pd.DataFrame(test.drop(columns_to_encode, axis=1))

# %%
# Perform one-hot encoding on the specified columns
train_encoded_1 = pd.get_dummies(X_train_bin[columns_to_encode])
train_encoded_1 = train_encoded_1.astype(int)

X_train_bin_encoded = pd.concat([train_encoded_1, other_columns_train], axis=1)
X_train_bin_encoded
# Out:
#               payer_code_BC  payer_code_CM  payer_code_CP  payer_code_HM  \
# encounter_id
# 119133                    0              0              0              0
# 532575                    0              0              0              0
# 909215                    0              0              0              0
# 662753                    0              1              0              0
# 694319                    1              0              0              0
# ...                     ...            ...            ...            ...
# 327556                    0              0              0              0
# 998331                    0              0              0              0
# 210258                    0              0              0              0
# 875904                    0              0              0              0
# 828160                    0              0              0              0
#
#               payer_code_MC  payer_code_MD  payer_code_None  payer_code_OG  \
# encounter_id
# 119133                    0              0                0              0
# 532575                    0              0                1              0
# 909215                    0              0                1              0
# 662753                    0              0                0              0
# 694319                    0              0                0              0
# ...                     ...            ...              ...            ...
# 327556                    0              0                1              0
# 998331                    0              0                0              0
# 210258                    1              0                0              0
# 875904                    1              0                0              0
# 828160                    0              0                1              0
#
#               payer_code_Other_code  payer_code_SP  ...  Sulfonylureas  \
# encounter_id                                        ...
# 119133                            0              1  ...              0
# 532575                            0              0  ...              0
# 909215                            0              0  ...              1
# 662753                            0              0  ...              0
# 694319                            0              0  ...              1
# ...                             ...            ...  ...            ...
# 327556                            0              0  ...              0
# 998331                            1              0  ...              1
# 210258                            0              0  ...              0
# 875904                            0              0  ...              1
# 828160                            0              0  ...              0
#
#               Meglitinides  Thiazolidinediones  Alpha_Glucosidase_Inhibitors  \
# encounter_id
# 119133                   0                   0                             0
# 532575                   0                   0                             0
# 909215                   0                   0                             0
# 662753                   0                   0                             0
# 694319                   0                   1                             0
# ...                    ...                 ...                           ...
# 327556                   0                   0                             0
# 998331                   0                   1                             0
# 210258                   0                   0                             0
# 875904                   0                   0                             0
# 828160                   0                   0                             0
#
#               Midpoint_Age  gender_binary  presc_diabetes_meds_binary  \
# encounter_id
# 119133                55.0              1                           1
# 532575                15.0              0                           1
# 909215                55.0              1                           1
# 662753                65.0              0                           0
# 694319                45.0              0                           1
# ...                    ...            ...                         ...
# 327556                75.0              0                           0
# 998331                55.0              1                           1
# 210258                35.0              1                           0
# 875904                75.0              0                           1
# 828160                65.0              1                           1
#
#               change_in_meds_binary  Total_visits  Serious_condition_visits
# encounter_id
# 119133                            0             1                         1
# 532575                            0             0                         0
# 909215                            1             0                         0
# 662753                            0             1                         1
# 694319                            1             1                         1
# ...                             ...           ...                       ...
# 327556                            0             1                         1
# 998331                            1             4                         4
# 210258                            0             3                         2
# 875904                            0             0                         0
# 828160                            1             0                         0
#
# [53427 rows x 83 columns]

# %%
# Perform one-hot encoding on the specified columns
val_encoded_1 = pd.get_dummies(X_val_bin[columns_to_encode])
val_encoded_1 = val_encoded_1.astype(int)

X_val_bin_encoded = pd.concat([val_encoded_1, other_columns_val], axis=1)
X_val_bin_encoded
# Out:
#               payer_code_BC  payer_code_CM  payer_code_CP  payer_code_HM  \
# encounter_id
# 274568                    0              0              0              0
# 768397                    0              0              0              1
# 897606                    0              0              0              0
# 827973                    0              0              0              0
# 806134                    0              0              0              0
# ...                     ...            ...            ...            ...
# 158462                    0              0              0              0
# 599332                    0              0              0              0
# 432909                    0              0              0              0
# 289564                    0              0              0              0
# 703184                    0              0              0              0
#
#               payer_code_MC  payer_code_MD  payer_code_None  payer_code_OG  \
# encounter_id
# 274568                    0              0                1              0
# 768397                    0              0                0              0
# 897606                    0              0                1              0
# 827973                    0              0                1              0
# 806134                    0              0                1              0
# ...                     ...            ...              ...            ...
# 158462                    0              0                1              0
# 599332                    1              0                0              0
# 432909                    1              0                0              0
# 289564                    0              0                1              0
# 703184                    0              0                0              0
#
#               payer_code_Other_code  payer_code_SP  ...  Sulfonylureas  \
# encounter_id                                        ...
# 274568                            0              0  ...              0
# 768397                            0              0  ...              0
# 897606                            0              0  ...              0
# 827973                            0              0  ...              1
# 806134                            0              0  ...              0
# ...                             ...            ...  ...            ...
# 158462                            0              0  ...              0
# 599332                            0              0  ...              0
# 432909                            0              0  ...              0
# 289564                            0              0  ...              0
# 703184                            0              1  ...              0
#
#               Meglitinides  Thiazolidinediones  Alpha_Glucosidase_Inhibitors  \
# encounter_id
# 274568                   0                   0                             0
# 768397                   0                   0                             0
# 897606                   0                   0                             0
# 827973                   0                   0                             0
# 806134                   0                   0                             0
# ...                    ...                 ...                           ...
# 158462                   0                   0                             0
# 599332                   0                   0                             0
# 432909                   0                   0                             0
# 289564                   0                   1                             0
# 703184                   0                   0                             0
#
#               Midpoint_Age  gender_binary  presc_diabetes_meds_binary  \
# encounter_id
# 274568                55.0              0                           0
# 768397                55.0              1                           1
# 897606                45.0              1                           1
# 827973                75.0              0                           1
# 806134                55.0              1                           1
# ...                    ...            ...                         ...
# 158462                65.0              0                           1
# 599332                85.0              0                           1
# 432909                85.0              0                           1
# 289564                65.0              1                           1
# 703184                55.0              0                           1
#
#               change_in_meds_binary  Total_visits  Serious_condition_visits
# encounter_id
# 274568                            0             0                         0
# 768397                            0             0                         0
# 897606                            0             0                         0
# 827973                            0             0                         0
# 806134                            0             1                         1
# ...                             ...           ...                       ...
# 158462                            1             4                         1
# 599332                            0             0                         0
# 432909                            1             4                         4
# 289564                            1             0                         0
# 703184                            0             0                         0
#
# [17809 rows x 83 columns]

# %%
# Perform one-hot encoding on the specified columns
test_encoded_1 = pd.get_dummies(test[columns_to_encode])
test_encoded_1 = test_encoded_1.astype(int)

test_encoded = pd.concat([test_encoded_1, other_columns_test], axis=1)
test_encoded
# Out:
#               payer_code_BC  payer_code_CM  payer_code_CP  payer_code_HM  \
# encounter_id
# 499502                    0              0              0              1
# 447319                    0              0              0              1
# 309126                    0              0              0              0
# 181183                    1              0              0              0
# 359339                    0              0              0              0
# ...                     ...            ...            ...            ...
# 451150                    0              0              0              1
# 549298                    0              0              0              0
# 327586                    0              0              0              0
# 351214                    0              0              0              0
# 914270                    0              0              0              0
#
#               payer_code_MC  payer_code_MD  payer_code_None  \
# encounter_id
# 499502                    0              0                0
# 447319                    0              0                0
# 309126                    0              0                1
# 181183                    0              0                0
# 359339                    0              0                1
# ...                     ...            ...              ...
# 451150                    0              0                0
# 549298                    0              0                1
# 327586                    0              0                1
# 351214                    1              0                0
# 914270                    0              1                0
#
#               payer_code_Other_code  payer_code_SP  payer_code_UN  ...  \
# encounter_id                                                       ...
# 499502                            0              0              0  ...
# 447319                            0              0              0  ...
# 309126                            0              0              0  ...
# 181183                            0              0              0  ...
# 359339                            0              0              0  ...
# ...                             ...            ...            ...  ...
# 451150                            0              0              0  ...
# 549298                            0              0              0  ...
# 327586                            0              0              0  ...
# 351214                            0              0              0  ...
# 914270                            0              0              0  ...
#
#               Sulfonylureas  Meglitinides  Thiazolidinediones  \
# encounter_id
# 499502                    0             0                   0
# 447319                    0             0                   0
# 309126                    0             0                   0
# 181183                    1             0                   0
# 359339                    0             0                   0
# ...                     ...           ...                 ...
# 451150                    0             0                   0
# 549298                    0             0                   0
# 327586                    0             0                   0
# 351214                    1             0                   1
# 914270                    0             0                   1
#
#               Alpha_Glucosidase_Inhibitors  Midpoint_Age  gender_binary  \
# encounter_id
# 499502                                   0          85.0              1
# 447319                                   0          25.0              1
# 309126                                   0          35.0              1
# 181183                                   0          55.0              1
# 359339                                   0          65.0              1
# ...                                    ...           ...            ...
# 451150                                   0          75.0              1
# 549298                                   0          65.0              1
# 327586                                   0          85.0              0
# 351214                                   0           NaN              1
# 914270                                   0          65.0              0
#
#               presc_diabetes_meds_binary  change_in_meds_binary  Total_visits  \
# encounter_id
# 499502                                 1                      0             0
# 447319                                 0                      0             1
# 309126                                 1                      0             0
# 181183                                 1                      1             0
# 359339                                 1                      0             0
# ...                                  ...                    ...           ...
# 451150                                 0                      0             0
# 549298                                 1                      0             4
# 327586                                 1                      0             0
# 351214                                 1                      1             0
# 914270                                 1                      0             1
#
#               Serious_condition_visits
# encounter_id
# 499502                               0
# 447319                               1
# 309126                               0
# 181183                               0
# 359339                               0
# ...                                ...
# 451150                               0
# 549298                               4
# 327586                               0
# 351214                               0
# 914270                               1
#
# [30530 rows x 82 columns]

# %%
# Dropping payer_code_OG on train and val because it does not exist on test (got dropped when doing the >1% categories)

# %%
X_train_bin_encoded.drop(['payer_code_OG'], axis=1, inplace=True)
X_val_bin_encoded.drop(['payer_code_OG'], axis=1, inplace=True)

# %%
X_train_bin_encoded.shape
# Out:
# (53427, 82)

# %%
X_val_bin_encoded.shape
# Out:
# (17809, 82)

# %%
test_encoded.shape
# Out:
# (30530, 82)

# %%
y_val_bin.value_counts(normalize=True)
# Out:
# readmitted_multiclass
# No          0.539446
# >30 days    0.348981
# <30 days    0.111573
# Name: proportion, dtype: float64

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
y_train_encoded = pd.DataFrame(label_encoder.fit_transform(y_train_bin))
y_train_encoded.set_index(y_train_bin.index, inplace=True)

# %%
label_encoder = LabelEncoder()
y_val_encoded = pd.DataFrame(label_encoder.fit_transform(y_val_bin))
y_val_encoded.set_index(y_val_bin.index, inplace=True)

# %%
for categorical_columns2 in X_train_bin_encoded:
    TestIndependence(X_train_bin_encoded[categorical_columns2],y_train_bin, categorical_columns2, 0.05)
# Out:
# payer_code_BC is IMPORTANT for Prediction
# payer_code_CM is NOT an important predictor. (Discard payer_code_CM from model)
# payer_code_CP is IMPORTANT for Prediction
# payer_code_HM is IMPORTANT for Prediction
# payer_code_MC is IMPORTANT for Prediction
# payer_code_MD is NOT an important predictor. (Discard payer_code_MD from model)
# payer_code_None is NOT an important predictor. (Discard payer_code_None from model)
# payer_code_Other_code is IMPORTANT for Prediction
# payer_code_SP is IMPORTANT for Prediction
# payer_code_UN is IMPORTANT for Prediction
# admission_type_Elective is IMPORTANT for Prediction
# admission_type_Other_type is IMPORTANT for Prediction
# admission_type_Urgent/Emergency is IMPORTANT for Prediction
# medical_specialty_Cardiology is IMPORTANT for Prediction
# medical_specialty_Emergency_Trauma is IMPORTANT for Prediction
# medical_specialty_Family_GeneralPractice is NOT an important predictor. (Discard medical_specialty_Family_GeneralPractice from model)
# medical_specialty_InternalMedicine is IMPORTANT for Prediction
# medical_specialty_Other_specialty is IMPORTANT for Prediction
# medical_specialty_Surgery is IMPORTANT for Prediction
# discharge_disposition_Discharged_to_home is IMPORTANT for Prediction
# discharge_disposition_Expired is IMPORTANT for Prediction
# discharge_disposition_Other is IMPORTANT for Prediction
# discharge_disposition_Transferred_to_another_medical_facility is IMPORTANT for Prediction
# admission_source_Emergency_Room is IMPORTANT for Prediction
# admission_source_No_source is NOT an important predictor. (Discard admission_source_No_source from model)
# admission_source_Other_source is IMPORTANT for Prediction
# admission_source_Referral is IMPORTANT for Prediction
# primary_diagnosis_types_Circulatory is NOT an important predictor. (Discard primary_diagnosis_types_Circulatory from model)
# primary_diagnosis_types_Diabetes is IMPORTANT for Prediction
# primary_diagnosis_types_Digestive is NOT an important predictor. (Discard primary_diagnosis_types_Digestive from model)
# primary_diagnosis_types_Genitourinary is NOT an important predictor. (Discard primary_diagnosis_types_Genitourinary from model)
# primary_diagnosis_types_Injury is IMPORTANT for Prediction
# primary_diagnosis_types_Musculoskeletal is IMPORTANT for Prediction
# primary_diagnosis_types_Neoplasms is IMPORTANT for Prediction
# primary_diagnosis_types_Other is NOT an important predictor. (Discard primary_diagnosis_types_Other from model)
# primary_diagnosis_types_Respiratory is IMPORTANT for Prediction
# secondary_diagnosis_types_Circulatory is IMPORTANT for Prediction
# secondary_diagnosis_types_Diabetes is IMPORTANT for Prediction
# secondary_diagnosis_types_Digestive is NOT an important predictor. (Discard secondary_diagnosis_types_Digestive from model)
# secondary_diagnosis_types_Genitourinary is NOT an important predictor. (Discard secondary_diagnosis_types_Genitourinary from model)
# secondary_diagnosis_types_Injury is IMPORTANT for Prediction
# secondary_diagnosis_types_Musculoskeletal is NOT an important predictor. (Discard secondary_diagnosis_types_Musculoskeletal from model)
# secondary_diagnosis_types_Neoplasms is IMPORTANT for Prediction
# secondary_diagnosis_types_Other is NOT an important predictor. (Discard secondary_diagnosis_types_Other from model)
# secondary_diagnosis_types_Respiratory is IMPORTANT for Prediction
# additional_diagnosis_types_Circulatory is IMPORTANT for Prediction
# additional_diagnosis_types_Diabetes is IMPORTANT for Prediction
# additional_diagnosis_types_Digestive is NOT an important predictor. (Discard additional_diagnosis_types_Digestive from model)
# additional_diagnosis_types_Genitourinary is IMPORTANT for Prediction
# additional_diagnosis_types_Injury is IMPORTANT for Prediction
# additional_diagnosis_types_Musculoskeletal is NOT an important predictor. (Discard additional_diagnosis_types_Musculoskeletal from model)
# additional_diagnosis_types_Neoplasms is IMPORTANT for Prediction
# additional_diagnosis_types_Other is IMPORTANT for Prediction
# additional_diagnosis_types_Respiratory is IMPORTANT for Prediction
# glucose_test_result_High is IMPORTANT for Prediction
# glucose_test_result_Norm is NOT an important predictor. (Discard glucose_test_result_Norm from model)
# glucose_test_result_Not_taken is IMPORTANT for Prediction
# a1c_test_result_High is IMPORTANT for Prediction
# a1c_test_result_Norm is IMPORTANT for Prediction
# a1c_test_result_Not_taken is IMPORTANT for Prediction
# outpatient_visits is IMPORTANT for Prediction
# emergency_visits is IMPORTANT for Prediction
# inpatient_visits is IMPORTANT for Prediction
# length_of_stay is IMPORTANT for Prediction
# number_lab_tests is IMPORTANT for Prediction
# non_lab_procedures is IMPORTANT for Prediction
# number_of_medications is IMPORTANT for Prediction
# number_diagnoses is IMPORTANT for Prediction
# race_caucasian is IMPORTANT for Prediction
# number_generic_medications is IMPORTANT for Prediction
# metformin is IMPORTANT for Prediction
# insulin is IMPORTANT for Prediction
# Sulfonylureas is IMPORTANT for Prediction
# Meglitinides is IMPORTANT for Prediction
# Thiazolidinediones is IMPORTANT for Prediction
# Alpha_Glucosidase_Inhibitors is IMPORTANT for Prediction
# Midpoint_Age is IMPORTANT for Prediction
# gender_binary is IMPORTANT for Prediction
# presc_diabetes_meds_binary is IMPORTANT for Prediction
# change_in_meds_binary is IMPORTANT for Prediction
# Total_visits is IMPORTANT for Prediction
# Serious_condition_visits is IMPORTANT for Prediction

# %%
X_train_bin_encoded.drop(['payer_code_CM','payer_code_MD','payer_code_None','medical_specialty_Family_GeneralPractice',
                          'admission_source_No_source','primary_diagnosis_types_Circulatory','primary_diagnosis_types_Digestive',
                          'primary_diagnosis_types_Genitourinary','primary_diagnosis_types_Other','secondary_diagnosis_types_Digestive',
                          'secondary_diagnosis_types_Genitourinary','secondary_diagnosis_types_Musculoskeletal',
                          'secondary_diagnosis_types_Other','additional_diagnosis_types_Digestive',
                          'additional_diagnosis_types_Musculoskeletal','glucose_test_result_Norm'],axis = 1, inplace = True)

X_val_bin_encoded.drop(['payer_code_CM','payer_code_MD','payer_code_None','medical_specialty_Family_GeneralPractice',
                          'admission_source_No_source','primary_diagnosis_types_Circulatory','primary_diagnosis_types_Digestive',
                          'primary_diagnosis_types_Genitourinary','primary_diagnosis_types_Other','secondary_diagnosis_types_Digestive',
                          'secondary_diagnosis_types_Genitourinary','secondary_diagnosis_types_Musculoskeletal',
                          'secondary_diagnosis_types_Other','additional_diagnosis_types_Digestive',
                          'additional_diagnosis_types_Musculoskeletal','glucose_test_result_Norm'],axis = 1, inplace = True)

test_encoded.drop(['payer_code_CM','payer_code_MD','payer_code_None','medical_specialty_Family_GeneralPractice',
                          'admission_source_No_source','primary_diagnosis_types_Circulatory','primary_diagnosis_types_Digestive',
                          'primary_diagnosis_types_Genitourinary','primary_diagnosis_types_Other','secondary_diagnosis_types_Digestive',
                          'secondary_diagnosis_types_Genitourinary','secondary_diagnosis_types_Musculoskeletal',
                          'secondary_diagnosis_types_Other','additional_diagnosis_types_Digestive',
                          'additional_diagnosis_types_Musculoskeletal','glucose_test_result_Norm'],axis = 1, inplace = True)

# %%
X_train_bin_encoded.shape
# Out:
# (53427, 66)

# %%
X_val_bin_encoded.shape
# Out:
# (17809, 66)

# %%
test_encoded.shape
# Out:
# (30530, 66)

# %% [markdown]
# ## Imputing age

# %%
train['Midpoint_Age'].isna().sum()
# Out:
# 2217

# %%
X_train_bin_encoded['Midpoint_Age'].value_counts()
# Out:
# Midpoint_Age
# 75.0    13292
# 65.0    11449
# 85.0     8769
# 55.0     8732
# 45.0     4894
# 35.0     1934
# 95.0     1440
# 25.0      829
# 15.0      357
# 5.0        78
# Name: count, dtype: int64

# %%
X_train_bin_encoded['Midpoint_Age'].isna().sum()
# Out:
# 1653

# %%
X_val_bin_encoded['Midpoint_Age'].isna().sum()
# Out:
# 564

# %%
test_encoded['Midpoint_Age'].isna().sum()
# Out:
# 1194

# %%
known_age = X_train_bin_encoded[X_train_bin_encoded['Midpoint_Age'].notnull()]
unknown_age = X_train_bin_encoded[X_train_bin_encoded['Midpoint_Age'].isnull()]

# Reset indices
known_age = known_age.reset_index(drop=True)
unknown_age = unknown_age.reset_index(drop=True)

# Create the training data for the model
X = known_age.drop(['Midpoint_Age'], axis=1)
y = known_age['Midpoint_Age']

# Fit the model
regr = RandomForestRegressor(random_state=0, n_estimators=200, n_jobs=-1)
regr.fit(X, y)

# Predict the missing ages
predicted_ages = regr.predict(unknown_age.drop(['Midpoint_Age'], axis=1))

# Fill in the missing values using the original indices
X_train_bin_encoded.loc[X_train_bin_encoded['Midpoint_Age'].isnull(), 'Midpoint_Age'] = predicted_ages

# %%
known_age = X_val_bin_encoded[X_val_bin_encoded['Midpoint_Age'].notnull()]
unknown_age = X_val_bin_encoded[X_val_bin_encoded['Midpoint_Age'].isnull()]

# Reset indices
known_age = known_age.reset_index(drop=True)
unknown_age = unknown_age.reset_index(drop=True)

# Predict the missing ages
predicted_ages = regr.predict(unknown_age.drop(['Midpoint_Age'], axis=1))

# Fill in the missing values using the original indices
X_val_bin_encoded.loc[X_val_bin_encoded['Midpoint_Age'].isnull(), 'Midpoint_Age'] = predicted_ages

# %%
known_age = test_encoded[test_encoded['Midpoint_Age'].notnull()]
unknown_age = test_encoded[test_encoded['Midpoint_Age'].isnull()]

# Reset indices
known_age = known_age.reset_index(drop=True)
unknown_age = unknown_age.reset_index(drop=True)

# Predict the missing ages
predicted_ages = regr.predict(unknown_age.drop(['Midpoint_Age'], axis=1))

# Fill in the missing values using the original indices
test_encoded.loc[test_encoded['Midpoint_Age'].isnull(), 'Midpoint_Age'] = predicted_ages

# %%
X_train_bin_encoded['Midpoint_Age'].isna().sum()
# Out:
# 0

# %%
X_val_bin_encoded['Midpoint_Age'].isna().sum()
# Out:
# 0

# %%
test_encoded['Midpoint_Age'].isna().sum()
# Out:
# 0

# %%
X_train_bin_encoded.head()
# Out:
#               payer_code_BC  payer_code_CP  payer_code_HM  payer_code_MC  \
# encounter_id
# 119133                    0              0              0              0
# 532575                    0              0              0              0
# 909215                    0              0              0              0
# 662753                    0              0              0              0
# 694319                    1              0              0              0
#
#               payer_code_Other_code  payer_code_SP  payer_code_UN  \
# encounter_id
# 119133                            0              1              0
# 532575                            0              0              0
# 909215                            0              0              0
# 662753                            0              0              0
# 694319                            0              0              0
#
#               admission_type_Elective  admission_type_Other_type  \
# encounter_id
# 119133                              0                          0
# 532575                              0                          0
# 909215                              0                          1
# 662753                              0                          0
# 694319                              1                          0
#
#               admission_type_Urgent/Emergency  ...  Sulfonylureas  \
# encounter_id                                   ...
# 119133                                      1  ...              0
# 532575                                      1  ...              0
# 909215                                      0  ...              1
# 662753                                      1  ...              0
# 694319                                      0  ...              1
#
#               Meglitinides  Thiazolidinediones  Alpha_Glucosidase_Inhibitors  \
# encounter_id
# 119133                   0                   0                             0
# 532575                   0                   0                             0
# 909215                   0                   0                             0
# 662753                   0                   0                             0
# 694319                   0                   1                             0
#
#               Midpoint_Age  gender_binary  presc_diabetes_meds_binary  \
# encounter_id
# 119133                55.0              1                           1
# 532575                15.0              0                           1
# 909215                55.0              1                           1
# 662753                65.0              0                           0
# 694319                45.0              0                           1
#
#               change_in_meds_binary  Total_visits  Serious_condition_visits
# encounter_id
# 119133                            0             1                         1
# 532575                            0             0                         0
# 909215                            1             0                         0
# 662753                            0             1                         1
# 694319                            1             1                         1
#
# [5 rows x 66 columns]

# %%
X_val_bin_encoded.head()
# Out:
#               payer_code_BC  payer_code_CP  payer_code_HM  payer_code_MC  \
# encounter_id
# 274568                    0              0              0              0
# 768397                    0              0              1              0
# 897606                    0              0              0              0
# 827973                    0              0              0              0
# 806134                    0              0              0              0
#
#               payer_code_Other_code  payer_code_SP  payer_code_UN  \
# encounter_id
# 274568                            0              0              0
# 768397                            0              0              0
# 897606                            0              0              0
# 827973                            0              0              0
# 806134                            0              0              0
#
#               admission_type_Elective  admission_type_Other_type  \
# encounter_id
# 274568                              1                          0
# 768397                              0                          0
# 897606                              0                          0
# 827973                              0                          0
# 806134                              0                          0
#
#               admission_type_Urgent/Emergency  ...  Sulfonylureas  \
# encounter_id                                   ...
# 274568                                      0  ...              0
# 768397                                      1  ...              0
# 897606                                      1  ...              0
# 827973                                      1  ...              1
# 806134                                      1  ...              0
#
#               Meglitinides  Thiazolidinediones  Alpha_Glucosidase_Inhibitors  \
# encounter_id
# 274568                   0                   0                             0
# 768397                   0                   0                             0
# 897606                   0                   0                             0
# 827973                   0                   0                             0
# 806134                   0                   0                             0
#
#               Midpoint_Age  gender_binary  presc_diabetes_meds_binary  \
# encounter_id
# 274568                55.0              0                           0
# 768397                55.0              1                           1
# 897606                45.0              1                           1
# 827973                75.0              0                           1
# 806134                55.0              1                           1
#
#               change_in_meds_binary  Total_visits  Serious_condition_visits
# encounter_id
# 274568                            0             0                         0
# 768397                            0             0                         0
# 897606                            0             0                         0
# 827973                            0             0                         0
# 806134                            0             1                         1
#
# [5 rows x 66 columns]

# %%
test_encoded.head()
# Out:
#               payer_code_BC  payer_code_CP  payer_code_HM  payer_code_MC  \
# encounter_id
# 499502                    0              0              1              0
# 447319                    0              0              1              0
# 309126                    0              0              0              0
# 181183                    1              0              0              0
# 359339                    0              0              0              0
#
#               payer_code_Other_code  payer_code_SP  payer_code_UN  \
# encounter_id
# 499502                            0              0              0
# 447319                            0              0              0
# 309126                            0              0              0
# 181183                            0              0              0
# 359339                            0              0              0
#
#               admission_type_Elective  admission_type_Other_type  \
# encounter_id
# 499502                              0                          0
# 447319                              0                          0
# 309126                              0                          0
# 181183                              0                          1
# 359339                              0                          0
#
#               admission_type_Urgent/Emergency  ...  Sulfonylureas  \
# encounter_id                                   ...
# 499502                                      1  ...              0
# 447319                                      1  ...              0
# 309126                                      1  ...              0
# 181183                                      0  ...              1
# 359339                                      1  ...              0
#
#               Meglitinides  Thiazolidinediones  Alpha_Glucosidase_Inhibitors  \
# encounter_id
# 499502                   0                   0                             0
# 447319                   0                   0                             0
# 309126                   0                   0                             0
# 181183                   0                   0                             0
# 359339                   0                   0                             0
#
#               Midpoint_Age  gender_binary  presc_diabetes_meds_binary  \
# encounter_id
# 499502                85.0              1                           1
# 447319                25.0              1                           0
# 309126                35.0              1                           1
# 181183                55.0              1                           1
# 359339                65.0              1                           1
#
#               change_in_meds_binary  Total_visits  Serious_condition_visits
# encounter_id
# 499502                            0             0                         0
# 447319                            0             1                         1
# 309126                            0             0                         0
# 181183                            1             0                         0
# 359339                            0             0                         0
#
# [5 rows x 66 columns]

# %%
X_train_bin_encoded.columns
# Out:
# Index(['payer_code_BC', 'payer_code_CP', 'payer_code_HM', 'payer_code_MC',
#        'payer_code_Other_code', 'payer_code_SP', 'payer_code_UN',
#        'admission_type_Elective', 'admission_type_Other_type',
#        'admission_type_Urgent/Emergency', 'medical_specialty_Cardiology',
#        'medical_specialty_Emergency_Trauma',
#        'medical_specialty_InternalMedicine',
#        'medical_specialty_Other_specialty', 'medical_specialty_Surgery',
#        'discharge_disposition_Discharged_to_home',
#        'discharge_disposition_Expired', 'discharge_disposition_Other',
#        'discharge_disposition_Transferred_to_another_medical_facility',
#        'admission_source_Emergency_Room', 'admission_source_Other_source',
#        'admission_source_Referral', 'primary_diagnosis_types_Diabetes',
#        'primary_diagnosis_types_Injury',
#        'primary_diagnosis_types_Musculoskeletal',
#        'primary_diagnosis_types_Neoplasms',
#        'primary_diagnosis_types_Respiratory',
#        'secondary_diagnosis_types_Circulatory',
#        'secondary_diagnosis_types_Diabetes',
#        'secondary_diagnosis_types_Injury',
#        'secondary_diagnosis_types_Neoplasms',
#        'secondary_diagnosis_types_Respiratory',
#        'additional_diagnosis_types_Circulatory',
#        'additional_diagnosis_types_Diabetes',
#        'additional_diagnosis_types_Genitourinary',
#        'additional_diagnosis_types_Injury',
#        'additional_diagnosis_types_Neoplasms',
#        'additional_diagnosis_types_Other',
#        'additional_diagnosis_types_Respiratory', 'glucose_test_result_High',
#        'glucose_test_result_Not_taken', 'a1c_test_result_High',
#        'a1c_test_result_Norm', 'a1c_test_result_Not_taken',
#        'outpatient_visits', 'emergency_visits', 'inpatient_visits',
#        'length_of_stay', 'number_lab_tests', 'non_lab_procedures',
#        'number_of_medications', 'number_diagnoses', 'race_caucasian',
#        'number_generic_medications', 'metformin', 'insulin', 'Sulfonylureas',
#        'Meglitinides', 'Thiazolidinediones', 'Alpha_Glucosidase_Inhibitors',
#        'Midpoint_Age', 'gender_binary', 'presc_diabetes_meds_binary',
#        'change_in_meds_binary', 'Total_visits', 'Serious_condition_visits'],
#       dtype='object')

# %%
X_train_bin_encoded.columns
# Out:
# Index(['payer_code_BC', 'payer_code_CP', 'payer_code_HM', 'payer_code_MC',
#        'payer_code_Other_code', 'payer_code_SP', 'payer_code_UN',
#        'admission_type_Elective', 'admission_type_Other_type',
#        'admission_type_Urgent/Emergency', 'medical_specialty_Cardiology',
#        'medical_specialty_Emergency_Trauma',
#        'medical_specialty_InternalMedicine',
#        'medical_specialty_Other_specialty', 'medical_specialty_Surgery',
#        'discharge_disposition_Discharged_to_home',
#        'discharge_disposition_Expired', 'discharge_disposition_Other',
#        'discharge_disposition_Transferred_to_another_medical_facility',
#        'admission_source_Emergency_Room', 'admission_source_Other_source',
#        'admission_source_Referral', 'primary_diagnosis_types_Diabetes',
#        'primary_diagnosis_types_Injury',
#        'primary_diagnosis_types_Musculoskeletal',
#        'primary_diagnosis_types_Neoplasms',
#        'primary_diagnosis_types_Respiratory',
#        'secondary_diagnosis_types_Circulatory',
#        'secondary_diagnosis_types_Diabetes',
#        'secondary_diagnosis_types_Injury',
#        'secondary_diagnosis_types_Neoplasms',
#        'secondary_diagnosis_types_Respiratory',
#        'additional_diagnosis_types_Circulatory',
#        'additional_diagnosis_types_Diabetes',
#        'additional_diagnosis_types_Genitourinary',
#        'additional_diagnosis_types_Injury',
#        'additional_diagnosis_types_Neoplasms',
#        'additional_diagnosis_types_Other',
#        'additional_diagnosis_types_Respiratory', 'glucose_test_result_High',
#        'glucose_test_result_Not_taken', 'a1c_test_result_High',
#        'a1c_test_result_Norm', 'a1c_test_result_Not_taken',
#        'outpatient_visits', 'emergency_visits', 'inpatient_visits',
#        'length_of_stay', 'number_lab_tests', 'non_lab_procedures',
#        'number_of_medications', 'number_diagnoses', 'race_caucasian',
#        'number_generic_medications', 'metformin', 'insulin', 'Sulfonylureas',
#        'Meglitinides', 'Thiazolidinediones', 'Alpha_Glucosidase_Inhibitors',
#        'Midpoint_Age', 'gender_binary', 'presc_diabetes_meds_binary',
#        'change_in_meds_binary', 'Total_visits', 'Serious_condition_visits'],
#       dtype='object')

# %%
test_encoded.columns
# Out:
# Index(['payer_code_BC', 'payer_code_CP', 'payer_code_HM', 'payer_code_MC',
#        'payer_code_Other_code', 'payer_code_SP', 'payer_code_UN',
#        'admission_type_Elective', 'admission_type_Other_type',
#        'admission_type_Urgent/Emergency', 'medical_specialty_Cardiology',
#        'medical_specialty_Emergency_Trauma',
#        'medical_specialty_InternalMedicine',
#        'medical_specialty_Other_specialty', 'medical_specialty_Surgery',
#        'discharge_disposition_Discharged_to_home',
#        'discharge_disposition_Expired', 'discharge_disposition_Other',
#        'discharge_disposition_Transferred_to_another_medical_facility',
#        'admission_source_Emergency_Room', 'admission_source_Other_source',
#        'admission_source_Referral', 'primary_diagnosis_types_Diabetes',
#        'primary_diagnosis_types_Injury',
#        'primary_diagnosis_types_Musculoskeletal',
#        'primary_diagnosis_types_Neoplasms',
#        'primary_diagnosis_types_Respiratory',
#        'secondary_diagnosis_types_Circulatory',
#        'secondary_diagnosis_types_Diabetes',
#        'secondary_diagnosis_types_Injury',
#        'secondary_diagnosis_types_Neoplasms',
#        'secondary_diagnosis_types_Respiratory',
#        'additional_diagnosis_types_Circulatory',
#        'additional_diagnosis_types_Diabetes',
#        'additional_diagnosis_types_Genitourinary',
#        'additional_diagnosis_types_Injury',
#        'additional_diagnosis_types_Neoplasms',
#        'additional_diagnosis_types_Other',
#        'additional_diagnosis_types_Respiratory', 'glucose_test_result_High',
#        'glucose_test_result_Not_taken', 'a1c_test_result_High',
#        'a1c_test_result_Norm', 'a1c_test_result_Not_taken',
#        'outpatient_visits', 'emergency_visits', 'inpatient_visits',
#        'length_of_stay', 'number_lab_tests', 'non_lab_procedures',
#        'number_of_medications', 'number_diagnoses', 'race_caucasian',
#        'number_generic_medications', 'metformin', 'insulin', 'Sulfonylureas',
#        'Meglitinides', 'Thiazolidinediones', 'Alpha_Glucosidase_Inhibitors',
#        'Midpoint_Age', 'gender_binary', 'presc_diabetes_meds_binary',
#        'change_in_meds_binary', 'Total_visits', 'Serious_condition_visits'],
#       dtype='object')

# %%
y_train_encoded.value_counts(normalize=True)
# Out:
# 2    0.539016
# 1    0.349374
# 0    0.111610
# Name: proportion, dtype: float64

# %%
X_train_bin_encoded.to_csv('X_train_multiclass.csv', index=True)
X_val_bin_encoded.to_csv('X_val_multiclass.csv', index=True)
y_train_encoded.to_csv('y_train_multiclass.csv', index=True)
y_val_encoded.to_csv('y_val_multiclass.csv', index=True)
test_encoded.to_csv('test_multiclass.csv', index=True)
